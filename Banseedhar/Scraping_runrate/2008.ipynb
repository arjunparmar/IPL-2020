# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
URL="https://www.espncricinfo.com/ipl/engine/match/index/series.html?search=Indian+Premier+League;series=3519"

# %%
content = requests.get(URL)
soup = BeautifulSoup(content.text, 'html.parser')
row = soup.find_all('span',{"class":"bold"})

# %%
x=[]
for i in row:
    x.append(i.text)
x
# Out:
# ['Apr 18, 2008',
#  '222/3 (20 ov)',
#  '82 (15.1/20 ov)',
#  'Kolkata Knight Riders won by 140 runs',
#  'Apr 19, 2008',
#  '240/5 (20 ov)',
#  '207/4 (20 ov)',
#  'Chennai Super Kings won by 33 runs',
#  'Apr 19, 2008',
#  '129/8 (20 ov)',
#  '132/1 (15.1/20 ov)',
#  'Delhi Daredevils won by 9 wickets (with 29 balls remaining)',
#  'Apr 20, 2008',
#  '110 (18.4/20 ov)',
#  '112/5 (19/20 ov)',
#  'Kolkata Knight Riders won by 5 wickets (with 6 balls remaining)',
#  'Apr 20, 2008',
#  '165/6 (20 ov)',
#  '166/5 (19.4/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 2 balls remaining)',
#  'Apr 21, 2008',
#  '166/8 (20 ov)',
#  '168/4 (18.1/20 ov)',
#  'Rajasthan Royals won by 6 wickets (with 11 balls remaining)',
#  'Apr 22, 2008',
#  '142/8 (20 ov)',
#  '143/1 (13/20 ov)',
#  'Delhi Daredevils won by 9 wickets (with 42 balls remaining)',
#  'Apr 23, 2008',
#  '208/5 (20 ov)',
#  '202/7 (20 ov)',
#  'Chennai Super Kings won by 6 runs',
#  'Apr 24, 2008',
#  '214/5 (20 ov)',
#  '217/7 (19.5/20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 1 ball remaining)',
#  'Apr 25, 2008',
#  '182 (20 ov)',
#  '116/9 (20 ov)',
#  'Kings XI Punjab won by 66 runs',
#  'Apr 26, 2008',
#  '147/9 (20 ov)',
#  '152/1 (17/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 18 balls remaining)',
#  'Apr 26, 2008',
#  '135/8 (20 ov)',
#  '138/3 (17.1/20 ov)',
#  'Rajasthan Royals won by 7 wickets (with 17 balls remaining)',
#  'Apr 27, 2008',
#  '158/8 (20 ov)',
#  '162/6 (19.3/20 ov)',
#  'Kings XI Punjab won by 4 wickets (with 3 balls remaining)',
#  'Apr 27, 2008',
#  '154/7 (20 ov)',
#  '155/0 (12/20 ov)',
#  'Deccan Chargers won by 10 wickets (with 48 balls remaining)',
#  'Apr 28, 2008',
#  '178/5 (20 ov)',
#  '165 (19.4/20 ov)',
#  'Chennai Super Kings won by 13 runs',
#  'Apr 29, 2008',
#  '137/8 (20 ov)',
#  '138/3 (18.4/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 8 balls remaining)',
#  'Apr 30, 2008',
#  '191/5 (20 ov)',
#  '181/5 (20 ov)',
#  'Delhi Daredevils won by 10 runs',
#  'May 1, 2008',
#  '196/7 (20 ov)',
#  '151 (19.1/20 ov)',
#  'Rajasthan Royals won by 45 runs',
#  'May 1, 2008',
#  '164/8 (20 ov)',
#  '167/3 (18.5/20 ov)',
#  'Kings XI Punjab won by 7 wickets (with 7 balls remaining)',
#  'May 2, 2008',
#  '169/6 (20 ov)',
#  '172/2 (19/20 ov)',
#  'Delhi Daredevils won by 8 wickets (with 6 balls remaining)',
#  'May 3, 2008',
#  '156/8 (20 ov)',
#  '153/6 (20 ov)',
#  'Royal Challengers Bangalore won by 3 runs',
#  'May 3, 2008',
#  '178/6 (20 ov)',
#  '169/6 (20 ov)',
#  'Kings XI Punjab won by 9 runs',
#  'May 4, 2008',
#  '162/8 (20 ov)',
#  '133 (18.5/20 ov)',
#  'Mumbai Indians won by 29 runs',
#  'May 4, 2008',
#  '109 (19/20 ov)',
#  '110/2 (14.2/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 34 balls remaining)',
#  'May 5, 2008',
#  '126 (19.2/20 ov)',
#  '127/4 (18.2/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 10 balls remaining)',
#  'May 6, 2008',
#  '144/7 (20 ov)',
#  '148/3 (18/20 ov)',
#  'Deccan Chargers won by 7 wickets (with 12 balls remaining)',
#  'May 7, 2008',
#  '103 (16.2/20 ov)',
#  '104/3 (15.1/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 29 balls remaining)',
#  'May 8, 2008',
#  '187/5 (20 ov)',
#  '188/6 (20 ov)',
#  'Chennai Super Kings won by 4 wickets (with 0 balls remaining)',
#  'May 8, 2008',
#  '129/7 (16 ov)',
#  '124/4 (16 ov)',
#  'Kolkata Knight Riders won by 5 runs',
#  'May 9, 2008',
#  '140/8 (20 ov)',
#  '141/2 (16/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 24 balls remaining)',
#  'May 10, 2008',
#  '181/4 (20 ov)',
#  '163/9 (20 ov)',
#  'Chennai Super Kings won by 18 runs',
#  'May 11, 2008',
#  '204/4 (20 ov)',
#  '181/7 (20 ov)',
#  'Kolkata Knight Riders won by 23 runs',
#  'May 11, 2008',
#  '156/7 (20 ov)',
#  '159/7 (19.1/20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 5 balls remaining)',
#  'May 12, 2008',
#  '143/8 (20 ov)',
#  '144/1 (15.4/20 ov)',
#  'Kings XI Punjab won by 9 wickets (with 26 balls remaining)',
#  'May 13, 2008',
#  '133/6 (20 ov)',
#  '110 (17.5/20 ov)',
#  'Kolkata Knight Riders won by 23 runs',
#  'May 14, 2008',
#  '156/6 (20 ov)',
#  '158/1 (13.5/20 ov)',
#  'Mumbai Indians won by 9 wickets (with 37 balls remaining)',
#  'May 15, 2008',
#  '194/4 (20 ov)',
#  '182/9 (20 ov)',
#  'Delhi Daredevils won by 12 runs',
#  'May 16, 2008',
#  '67 (15.2/20 ov)',
#  '68/2 (5.3/20 ov)',
#  'Mumbai Indians won by 8 wickets (with 87 balls remaining)',
#  'May 17, 2008',
#  '197/1 (20 ov)',
#  '132/9 (20 ov)',
#  'Rajasthan Royals won by 65 runs',
#  'May 17, 2008',
#  '118/4 (11 ov)',
#  '94/3 (8 ov, target: 89)',
#  'Kings XI Punjab won by 6 runs (D/L method)',
#  'May 18, 2008',
#  '149/5 (20 ov)',
#  '55/0 (8 ov, target: 53)',
#  'Chennai Super Kings won by 3 runs (D/L method)',
#  'May 18, 2008',
#  '178/7 (20 ov)',
#  '153/7 (20 ov)',
#  'Mumbai Indians won by 25 runs',
#  'May 19, 2008',
#  '154/7 (20 ov)',
#  '158/5 (18.2/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 10 balls remaining)',
#  'May 20, 2008',
#  '147/8 (20 ov)',
#  '150/4 (16.3/20 ov)',
#  'Rajasthan Royals won by 6 wickets (with 21 balls remaining)',
#  'May 21, 2008',
#  '189/4 (20 ov)',
#  '188 (20 ov)',
#  'Kings XI Punjab won by 1 run',
#  'May 21, 2008',
#  '126/8 (20 ov)',
#  '112/8 (20 ov)',
#  'Royal Challengers Bangalore won by 14 runs',
#  'May 22, 2008',
#  '',
#  '',
#  'Match abandoned without a ball bowled',
#  'May 23, 2008',
#  '175/4 (20 ov)',
#  '178/4 (19.3/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 3 balls remaining)',
#  'May 24, 2008',
#  '211/5 (20 ov)',
#  '201/7 (20 ov)',
#  'Rajasthan Royals won by 10 runs',
#  'May 24, 2008',
#  '176/8 (20 ov)',
#  '179/5 (19.5/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 1 ball remaining)',
#  'May 25, 2008',
#  '165 (20 ov)',
#  '171/5 (19/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 6 balls remaining)',
#  'May 25, 2008',
#  '174/6 (20 ov)',
#  '175/7 (19.4/20 ov)',
#  'Kolkata Knight Riders won by 3 wickets (with 2 balls remaining)',
#  'May 26, 2008',
#  '145/7 (20 ov)',
#  '146/5 (20 ov)',
#  'Rajasthan Royals won by 5 wickets (with 0 balls remaining)',
#  'May 27, 2008',
#  '147/8 (20 ov)',
#  '148/3 (19.2/20 ov)',
#  'Chennai Super Kings won by 7 wickets (with 4 balls remaining)',
#  'May 28, 2008',
#  '122/9 (18 ov)',
#  '126/1 (16/18 ov)',
#  'Mumbai Indians won by 9 wickets (with 12 balls remaining)',
#  'May 28, 2008',
#  '221/3 (20 ov)',
#  '180/7 (20 ov)',
#  'Kings XI Punjab won by 41 runs',
#  'May 30, 2008',
#  '192/9 (20 ov)',
#  '87 (16.1/20 ov)',
#  'Rajasthan Royals won by 105 runs',
#  'May 31, 2008',
#  '112/8 (20 ov)',
#  '116/1 (14.5/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 31 balls remaining)',
#  'Jun 1, 2008',
#  '163/5 (20 ov)',
#  '164/7 (20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 0 balls remaining)']

# %%
y=[]
for i in range(0,len(x)):
    if i%4 != 0:
        y.append(x[i])
y
# Out:
# ['222/3 (20 ov)',
#  '82 (15.1/20 ov)',
#  'Kolkata Knight Riders won by 140 runs',
#  '240/5 (20 ov)',
#  '207/4 (20 ov)',
#  'Chennai Super Kings won by 33 runs',
#  '129/8 (20 ov)',
#  '132/1 (15.1/20 ov)',
#  'Delhi Daredevils won by 9 wickets (with 29 balls remaining)',
#  '110 (18.4/20 ov)',
#  '112/5 (19/20 ov)',
#  'Kolkata Knight Riders won by 5 wickets (with 6 balls remaining)',
#  '165/6 (20 ov)',
#  '166/5 (19.4/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 2 balls remaining)',
#  '166/8 (20 ov)',
#  '168/4 (18.1/20 ov)',
#  'Rajasthan Royals won by 6 wickets (with 11 balls remaining)',
#  '142/8 (20 ov)',
#  '143/1 (13/20 ov)',
#  'Delhi Daredevils won by 9 wickets (with 42 balls remaining)',
#  '208/5 (20 ov)',
#  '202/7 (20 ov)',
#  'Chennai Super Kings won by 6 runs',
#  '214/5 (20 ov)',
#  '217/7 (19.5/20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 1 ball remaining)',
#  '182 (20 ov)',
#  '116/9 (20 ov)',
#  'Kings XI Punjab won by 66 runs',
#  '147/9 (20 ov)',
#  '152/1 (17/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 18 balls remaining)',
#  '135/8 (20 ov)',
#  '138/3 (17.1/20 ov)',
#  'Rajasthan Royals won by 7 wickets (with 17 balls remaining)',
#  '158/8 (20 ov)',
#  '162/6 (19.3/20 ov)',
#  'Kings XI Punjab won by 4 wickets (with 3 balls remaining)',
#  '154/7 (20 ov)',
#  '155/0 (12/20 ov)',
#  'Deccan Chargers won by 10 wickets (with 48 balls remaining)',
#  '178/5 (20 ov)',
#  '165 (19.4/20 ov)',
#  'Chennai Super Kings won by 13 runs',
#  '137/8 (20 ov)',
#  '138/3 (18.4/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 8 balls remaining)',
#  '191/5 (20 ov)',
#  '181/5 (20 ov)',
#  'Delhi Daredevils won by 10 runs',
#  '196/7 (20 ov)',
#  '151 (19.1/20 ov)',
#  'Rajasthan Royals won by 45 runs',
#  '164/8 (20 ov)',
#  '167/3 (18.5/20 ov)',
#  'Kings XI Punjab won by 7 wickets (with 7 balls remaining)',
#  '169/6 (20 ov)',
#  '172/2 (19/20 ov)',
#  'Delhi Daredevils won by 8 wickets (with 6 balls remaining)',
#  '156/8 (20 ov)',
#  '153/6 (20 ov)',
#  'Royal Challengers Bangalore won by 3 runs',
#  '178/6 (20 ov)',
#  '169/6 (20 ov)',
#  'Kings XI Punjab won by 9 runs',
#  '162/8 (20 ov)',
#  '133 (18.5/20 ov)',
#  'Mumbai Indians won by 29 runs',
#  '109 (19/20 ov)',
#  '110/2 (14.2/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 34 balls remaining)',
#  '126 (19.2/20 ov)',
#  '127/4 (18.2/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 10 balls remaining)',
#  '144/7 (20 ov)',
#  '148/3 (18/20 ov)',
#  'Deccan Chargers won by 7 wickets (with 12 balls remaining)',
#  '103 (16.2/20 ov)',
#  '104/3 (15.1/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 29 balls remaining)',
#  '187/5 (20 ov)',
#  '188/6 (20 ov)',
#  'Chennai Super Kings won by 4 wickets (with 0 balls remaining)',
#  '129/7 (16 ov)',
#  '124/4 (16 ov)',
#  'Kolkata Knight Riders won by 5 runs',
#  '140/8 (20 ov)',
#  '141/2 (16/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 24 balls remaining)',
#  '181/4 (20 ov)',
#  '163/9 (20 ov)',
#  'Chennai Super Kings won by 18 runs',
#  '204/4 (20 ov)',
#  '181/7 (20 ov)',
#  'Kolkata Knight Riders won by 23 runs',
#  '156/7 (20 ov)',
#  '159/7 (19.1/20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 5 balls remaining)',
#  '143/8 (20 ov)',
#  '144/1 (15.4/20 ov)',
#  'Kings XI Punjab won by 9 wickets (with 26 balls remaining)',
#  '133/6 (20 ov)',
#  '110 (17.5/20 ov)',
#  'Kolkata Knight Riders won by 23 runs',
#  '156/6 (20 ov)',
#  '158/1 (13.5/20 ov)',
#  'Mumbai Indians won by 9 wickets (with 37 balls remaining)',
#  '194/4 (20 ov)',
#  '182/9 (20 ov)',
#  'Delhi Daredevils won by 12 runs',
#  '67 (15.2/20 ov)',
#  '68/2 (5.3/20 ov)',
#  'Mumbai Indians won by 8 wickets (with 87 balls remaining)',
#  '197/1 (20 ov)',
#  '132/9 (20 ov)',
#  'Rajasthan Royals won by 65 runs',
#  '118/4 (11 ov)',
#  '94/3 (8 ov, target: 89)',
#  'Kings XI Punjab won by 6 runs (D/L method)',
#  '149/5 (20 ov)',
#  '55/0 (8 ov, target: 53)',
#  'Chennai Super Kings won by 3 runs (D/L method)',
#  '178/7 (20 ov)',
#  '153/7 (20 ov)',
#  'Mumbai Indians won by 25 runs',
#  '154/7 (20 ov)',
#  '158/5 (18.2/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 10 balls remaining)',
#  '147/8 (20 ov)',
#  '150/4 (16.3/20 ov)',
#  'Rajasthan Royals won by 6 wickets (with 21 balls remaining)',
#  '189/4 (20 ov)',
#  '188 (20 ov)',
#  'Kings XI Punjab won by 1 run',
#  '126/8 (20 ov)',
#  '112/8 (20 ov)',
#  'Royal Challengers Bangalore won by 14 runs',
#  '',
#  '',
#  'Match abandoned without a ball bowled',
#  '175/4 (20 ov)',
#  '178/4 (19.3/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 3 balls remaining)',
#  '211/5 (20 ov)',
#  '201/7 (20 ov)',
#  'Rajasthan Royals won by 10 runs',
#  '176/8 (20 ov)',
#  '179/5 (19.5/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 1 ball remaining)',
#  '165 (20 ov)',
#  '171/5 (19/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 6 balls remaining)',
#  '174/6 (20 ov)',
#  '175/7 (19.4/20 ov)',
#  'Kolkata Knight Riders won by 3 wickets (with 2 balls remaining)',
#  '145/7 (20 ov)',
#  '146/5 (20 ov)',
#  'Rajasthan Royals won by 5 wickets (with 0 balls remaining)',
#  '147/8 (20 ov)',
#  '148/3 (19.2/20 ov)',
#  'Chennai Super Kings won by 7 wickets (with 4 balls remaining)',
#  '122/9 (18 ov)',
#  '126/1 (16/18 ov)',
#  'Mumbai Indians won by 9 wickets (with 12 balls remaining)',
#  '221/3 (20 ov)',
#  '180/7 (20 ov)',
#  'Kings XI Punjab won by 41 runs',
#  '192/9 (20 ov)',
#  '87 (16.1/20 ov)',
#  'Rajasthan Royals won by 105 runs',
#  '112/8 (20 ov)',
#  '116/1 (14.5/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 31 balls remaining)',
#  '163/5 (20 ov)',
#  '164/7 (20 ov)',
#  'Rajasthan Royals won by 3 wickets (with 0 balls remaining)']

# %%
z=[]
for i in range(1,len(y)):
    if i%3 != 0:
        z.append(y[i-1]) 
z
# Out:
# ['222/3 (20 ov)',
#  '82 (15.1/20 ov)',
#  '240/5 (20 ov)',
#  '207/4 (20 ov)',
#  '129/8 (20 ov)',
#  '132/1 (15.1/20 ov)',
#  '110 (18.4/20 ov)',
#  '112/5 (19/20 ov)',
#  '165/6 (20 ov)',
#  '166/5 (19.4/20 ov)',
#  '166/8 (20 ov)',
#  '168/4 (18.1/20 ov)',
#  '142/8 (20 ov)',
#  '143/1 (13/20 ov)',
#  '208/5 (20 ov)',
#  '202/7 (20 ov)',
#  '214/5 (20 ov)',
#  '217/7 (19.5/20 ov)',
#  '182 (20 ov)',
#  '116/9 (20 ov)',
#  '147/9 (20 ov)',
#  '152/1 (17/20 ov)',
#  '135/8 (20 ov)',
#  '138/3 (17.1/20 ov)',
#  '158/8 (20 ov)',
#  '162/6 (19.3/20 ov)',
#  '154/7 (20 ov)',
#  '155/0 (12/20 ov)',
#  '178/5 (20 ov)',
#  '165 (19.4/20 ov)',
#  '137/8 (20 ov)',
#  '138/3 (18.4/20 ov)',
#  '191/5 (20 ov)',
#  '181/5 (20 ov)',
#  '196/7 (20 ov)',
#  '151 (19.1/20 ov)',
#  '164/8 (20 ov)',
#  '167/3 (18.5/20 ov)',
#  '169/6 (20 ov)',
#  '172/2 (19/20 ov)',
#  '156/8 (20 ov)',
#  '153/6 (20 ov)',
#  '178/6 (20 ov)',
#  '169/6 (20 ov)',
#  '162/8 (20 ov)',
#  '133 (18.5/20 ov)',
#  '109 (19/20 ov)',
#  '110/2 (14.2/20 ov)',
#  '126 (19.2/20 ov)',
#  '127/4 (18.2/20 ov)',
#  '144/7 (20 ov)',
#  '148/3 (18/20 ov)',
#  '103 (16.2/20 ov)',
#  '104/3 (15.1/20 ov)',
#  '187/5 (20 ov)',
#  '188/6 (20 ov)',
#  '129/7 (16 ov)',
#  '124/4 (16 ov)',
#  '140/8 (20 ov)',
#  '141/2 (16/20 ov)',
#  '181/4 (20 ov)',
#  '163/9 (20 ov)',
#  '204/4 (20 ov)',
#  '181/7 (20 ov)',
#  '156/7 (20 ov)',
#  '159/7 (19.1/20 ov)',
#  '143/8 (20 ov)',
#  '144/1 (15.4/20 ov)',
#  '133/6 (20 ov)',
#  '110 (17.5/20 ov)',
#  '156/6 (20 ov)',
#  '158/1 (13.5/20 ov)',
#  '194/4 (20 ov)',
#  '182/9 (20 ov)',
#  '67 (15.2/20 ov)',
#  '68/2 (5.3/20 ov)',
#  '197/1 (20 ov)',
#  '132/9 (20 ov)',
#  '118/4 (11 ov)',
#  '94/3 (8 ov, target: 89)',
#  '149/5 (20 ov)',
#  '55/0 (8 ov, target: 53)',
#  '178/7 (20 ov)',
#  '153/7 (20 ov)',
#  '154/7 (20 ov)',
#  '158/5 (18.2/20 ov)',
#  '147/8 (20 ov)',
#  '150/4 (16.3/20 ov)',
#  '189/4 (20 ov)',
#  '188 (20 ov)',
#  '126/8 (20 ov)',
#  '112/8 (20 ov)',
#  '',
#  '',
#  '175/4 (20 ov)',
#  '178/4 (19.3/20 ov)',
#  '211/5 (20 ov)',
#  '201/7 (20 ov)',
#  '176/8 (20 ov)',
#  '179/5 (19.5/20 ov)',
#  '165 (20 ov)',
#  '171/5 (19/20 ov)',
#  '174/6 (20 ov)',
#  '175/7 (19.4/20 ov)',
#  '145/7 (20 ov)',
#  '146/5 (20 ov)',
#  '147/8 (20 ov)',
#  '148/3 (19.2/20 ov)',
#  '122/9 (18 ov)',
#  '126/1 (16/18 ov)',
#  '221/3 (20 ov)',
#  '180/7 (20 ov)',
#  '192/9 (20 ov)',
#  '87 (16.1/20 ov)',
#  '112/8 (20 ov)',
#  '116/1 (14.5/20 ov)',
#  '163/5 (20 ov)',
#  '164/7 (20 ov)']

# %%
run=[]
for i in z:
    p=[]
    for k in i:
        if k != '/' and k !=' ':
            p.append(k)
        if k == '/' or k ==' ':
            break
    run.append(p)
run
# Out:
# [['2', '2', '2'],
#  ['8', '2'],
#  ['2', '4', '0'],
#  ['2', '0', '7'],
#  ['1', '2', '9'],
#  ['1', '3', '2'],
#  ['1', '1', '0'],
#  ['1', '1', '2'],
#  ['1', '6', '5'],
#  ['1', '6', '6'],
#  ['1', '6', '6'],
#  ['1', '6', '8'],
#  ['1', '4', '2'],
#  ['1', '4', '3'],
#  ['2', '0', '8'],
#  ['2', '0', '2'],
#  ['2', '1', '4'],
#  ['2', '1', '7'],
#  ['1', '8', '2'],
#  ['1', '1', '6'],
#  ['1', '4', '7'],
#  ['1', '5', '2'],
#  ['1', '3', '5'],
#  ['1', '3', '8'],
#  ['1', '5', '8'],
#  ['1', '6', '2'],
#  ['1', '5', '4'],
#  ['1', '5', '5'],
#  ['1', '7', '8'],
#  ['1', '6', '5'],
#  ['1', '3', '7'],
#  ['1', '3', '8'],
#  ['1', '9', '1'],
#  ['1', '8', '1'],
#  ['1', '9', '6'],
#  ['1', '5', '1'],
#  ['1', '6', '4'],
#  ['1', '6', '7'],
#  ['1', '6', '9'],
#  ['1', '7', '2'],
#  ['1', '5', '6'],
#  ['1', '5', '3'],
#  ['1', '7', '8'],
#  ['1', '6', '9'],
#  ['1', '6', '2'],
#  ['1', '3', '3'],
#  ['1', '0', '9'],
#  ['1', '1', '0'],
#  ['1', '2', '6'],
#  ['1', '2', '7'],
#  ['1', '4', '4'],
#  ['1', '4', '8'],
#  ['1', '0', '3'],
#  ['1', '0', '4'],
#  ['1', '8', '7'],
#  ['1', '8', '8'],
#  ['1', '2', '9'],
#  ['1', '2', '4'],
#  ['1', '4', '0'],
#  ['1', '4', '1'],
#  ['1', '8', '1'],
#  ['1', '6', '3'],
#  ['2', '0', '4'],
#  ['1', '8', '1'],
#  ['1', '5', '6'],
#  ['1', '5', '9'],
#  ['1', '4', '3'],
#  ['1', '4', '4'],
#  ['1', '3', '3'],
#  ['1', '1', '0'],
#  ['1', '5', '6'],
#  ['1', '5', '8'],
#  ['1', '9', '4'],
#  ['1', '8', '2'],
#  ['6', '7'],
#  ['6', '8'],
#  ['1', '9', '7'],
#  ['1', '3', '2'],
#  ['1', '1', '8'],
#  ['9', '4'],
#  ['1', '4', '9'],
#  ['5', '5'],
#  ['1', '7', '8'],
#  ['1', '5', '3'],
#  ['1', '5', '4'],
#  ['1', '5', '8'],
#  ['1', '4', '7'],
#  ['1', '5', '0'],
#  ['1', '8', '9'],
#  ['1', '8', '8'],
#  ['1', '2', '6'],
#  ['1', '1', '2'],
#  [],
#  [],
#  ['1', '7', '5'],
#  ['1', '7', '8'],
#  ['2', '1', '1'],
#  ['2', '0', '1'],
#  ['1', '7', '6'],
#  ['1', '7', '9'],
#  ['1', '6', '5'],
#  ['1', '7', '1'],
#  ['1', '7', '4'],
#  ['1', '7', '5'],
#  ['1', '4', '5'],
#  ['1', '4', '6'],
#  ['1', '4', '7'],
#  ['1', '4', '8'],
#  ['1', '2', '2'],
#  ['1', '2', '6'],
#  ['2', '2', '1'],
#  ['1', '8', '0'],
#  ['1', '9', '2'],
#  ['8', '7'],
#  ['1', '1', '2'],
#  ['1', '1', '6'],
#  ['1', '6', '3'],
#  ['1', '6', '4']]

# %%
runs=[]
for i in run:
    runs.append("".join(i))
runs
# Out:
# ['222',
#  '82',
#  '240',
#  '207',
#  '129',
#  '132',
#  '110',
#  '112',
#  '165',
#  '166',
#  '166',
#  '168',
#  '142',
#  '143',
#  '208',
#  '202',
#  '214',
#  '217',
#  '182',
#  '116',
#  '147',
#  '152',
#  '135',
#  '138',
#  '158',
#  '162',
#  '154',
#  '155',
#  '178',
#  '165',
#  '137',
#  '138',
#  '191',
#  '181',
#  '196',
#  '151',
#  '164',
#  '167',
#  '169',
#  '172',
#  '156',
#  '153',
#  '178',
#  '169',
#  '162',
#  '133',
#  '109',
#  '110',
#  '126',
#  '127',
#  '144',
#  '148',
#  '103',
#  '104',
#  '187',
#  '188',
#  '129',
#  '124',
#  '140',
#  '141',
#  '181',
#  '163',
#  '204',
#  '181',
#  '156',
#  '159',
#  '143',
#  '144',
#  '133',
#  '110',
#  '156',
#  '158',
#  '194',
#  '182',
#  '67',
#  '68',
#  '197',
#  '132',
#  '118',
#  '94',
#  '149',
#  '55',
#  '178',
#  '153',
#  '154',
#  '158',
#  '147',
#  '150',
#  '189',
#  '188',
#  '126',
#  '112',
#  '',
#  '',
#  '175',
#  '178',
#  '211',
#  '201',
#  '176',
#  '179',
#  '165',
#  '171',
#  '174',
#  '175',
#  '145',
#  '146',
#  '147',
#  '148',
#  '122',
#  '126',
#  '221',
#  '180',
#  '192',
#  '87',
#  '112',
#  '116',
#  '163',
#  '164']

# %%
for k in range(0,len(runs)):
    if runs[k]==' ':
        runs[k]=0
runs
# Out:
# ['222',
#  '82',
#  '240',
#  '207',
#  '129',
#  '132',
#  '110',
#  '112',
#  '165',
#  '166',
#  '166',
#  '168',
#  '142',
#  '143',
#  '208',
#  '202',
#  '214',
#  '217',
#  '182',
#  '116',
#  '147',
#  '152',
#  '135',
#  '138',
#  '158',
#  '162',
#  '154',
#  '155',
#  '178',
#  '165',
#  '137',
#  '138',
#  '191',
#  '181',
#  '196',
#  '151',
#  '164',
#  '167',
#  '169',
#  '172',
#  '156',
#  '153',
#  '178',
#  '169',
#  '162',
#  '133',
#  '109',
#  '110',
#  '126',
#  '127',
#  '144',
#  '148',
#  '103',
#  '104',
#  '187',
#  '188',
#  '129',
#  '124',
#  '140',
#  '141',
#  '181',
#  '163',
#  '204',
#  '181',
#  '156',
#  '159',
#  '143',
#  '144',
#  '133',
#  '110',
#  '156',
#  '158',
#  '194',
#  '182',
#  '67',
#  '68',
#  '197',
#  '132',
#  '118',
#  '94',
#  '149',
#  '55',
#  '178',
#  '153',
#  '154',
#  '158',
#  '147',
#  '150',
#  '189',
#  '188',
#  '126',
#  '112',
#  '',
#  '',
#  '175',
#  '178',
#  '211',
#  '201',
#  '176',
#  '179',
#  '165',
#  '171',
#  '174',
#  '175',
#  '145',
#  '146',
#  '147',
#  '148',
#  '122',
#  '126',
#  '221',
#  '180',
#  '192',
#  '87',
#  '112',
#  '116',
#  '163',
#  '164']

# %%
runs[92]=0
runs[93]=0
runs
# Out:
# ['222',
#  '82',
#  '240',
#  '207',
#  '129',
#  '132',
#  '110',
#  '112',
#  '165',
#  '166',
#  '166',
#  '168',
#  '142',
#  '143',
#  '208',
#  '202',
#  '214',
#  '217',
#  '182',
#  '116',
#  '147',
#  '152',
#  '135',
#  '138',
#  '158',
#  '162',
#  '154',
#  '155',
#  '178',
#  '165',
#  '137',
#  '138',
#  '191',
#  '181',
#  '196',
#  '151',
#  '164',
#  '167',
#  '169',
#  '172',
#  '156',
#  '153',
#  '178',
#  '169',
#  '162',
#  '133',
#  '109',
#  '110',
#  '126',
#  '127',
#  '144',
#  '148',
#  '103',
#  '104',
#  '187',
#  '188',
#  '129',
#  '124',
#  '140',
#  '141',
#  '181',
#  '163',
#  '204',
#  '181',
#  '156',
#  '159',
#  '143',
#  '144',
#  '133',
#  '110',
#  '156',
#  '158',
#  '194',
#  '182',
#  '67',
#  '68',
#  '197',
#  '132',
#  '118',
#  '94',
#  '149',
#  '55',
#  '178',
#  '153',
#  '154',
#  '158',
#  '147',
#  '150',
#  '189',
#  '188',
#  '126',
#  '112',
#  0,
#  0,
#  '175',
#  '178',
#  '211',
#  '201',
#  '176',
#  '179',
#  '165',
#  '171',
#  '174',
#  '175',
#  '145',
#  '146',
#  '147',
#  '148',
#  '122',
#  '126',
#  '221',
#  '180',
#  '192',
#  '87',
#  '112',
#  '116',
#  '163',
#  '164']

# %%
over=[]
for k in z:
    w=[]
    for t in range(len(k)):
        if k[t]=='(':
            w.append(k[t+1])
            if k[t+2] != " ":   
                w.append(k[t+2])
            if k[t+3] != ' ' and k[t+3] != '/' and k[t+3] !='o':
                w.append(k[t+3])
                if k[t+3]=='.':
                    w.append(k[t+4])
            break
    over.append(w)        
over
# Out:
# [['2', '0'],
#  ['1', '5', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '5', '.', '1'],
#  ['1', '8', '.', '4'],
#  ['1', '9'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['1', '8', '.', '1'],
#  ['2', '0'],
#  ['1', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7'],
#  ['2', '0'],
#  ['1', '7', '.', '1'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '2'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '9'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['1', '9'],
#  ['1', '4', '.', '2'],
#  ['1', '9', '.', '2'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['1', '8'],
#  ['1', '6', '.', '2'],
#  ['1', '5', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '6'],
#  ['1', '6'],
#  ['2', '0'],
#  ['1', '6'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['1', '5', '.', '4'],
#  ['2', '0'],
#  ['1', '7', '.', '5'],
#  ['2', '0'],
#  ['1', '3', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '5', '.', '2'],
#  ['5', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '1'],
#  ['8'],
#  ['2', '0'],
#  ['8'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['1', '6', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  [],
#  [],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['1', '9'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['1', '8'],
#  ['1', '6'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '6', '.', '1'],
#  ['2', '0'],
#  ['1', '4', '.', '5'],
#  ['2', '0'],
#  ['2', '0']]

# %%
overs=[]
for i in over:
    overs.append("".join(i))
    
overs
# Out:
# ['20',
#  '15.1',
#  '20',
#  '20',
#  '20',
#  '15.1',
#  '18.4',
#  '19',
#  '20',
#  '19.4',
#  '20',
#  '18.1',
#  '20',
#  '13',
#  '20',
#  '20',
#  '20',
#  '19.5',
#  '20',
#  '20',
#  '20',
#  '17',
#  '20',
#  '17.1',
#  '20',
#  '19.3',
#  '20',
#  '12',
#  '20',
#  '19.4',
#  '20',
#  '18.4',
#  '20',
#  '20',
#  '20',
#  '19.1',
#  '20',
#  '18.5',
#  '20',
#  '19',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '18.5',
#  '19',
#  '14.2',
#  '19.2',
#  '18.2',
#  '20',
#  '18',
#  '16.2',
#  '15.1',
#  '20',
#  '20',
#  '16',
#  '16',
#  '20',
#  '16',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '19.1',
#  '20',
#  '15.4',
#  '20',
#  '17.5',
#  '20',
#  '13.5',
#  '20',
#  '20',
#  '15.2',
#  '5.3',
#  '20',
#  '20',
#  '11',
#  '8',
#  '20',
#  '8',
#  '20',
#  '20',
#  '20',
#  '18.2',
#  '20',
#  '16.3',
#  '20',
#  '20',
#  '20',
#  '20',
#  '',
#  '',
#  '20',
#  '19.3',
#  '20',
#  '20',
#  '20',
#  '19.5',
#  '20',
#  '19',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '19.2',
#  '18',
#  '16',
#  '20',
#  '20',
#  '20',
#  '16.1',
#  '20',
#  '14.5',
#  '20',
#  '20']

# %%
runs1=[]
runs2=[]
for i in range(len(runs)):
    if i%2 ==0:
        
        runs1.append(runs[i])
    else:
        runs2.append(runs[i])
overs1=[]
overs2=[]
for i in range(len(overs)):
    if i%2 ==0:
        
        overs1.append(overs[i])
    else:
        overs2.append(overs[i]) 
print(overs2)
# Out:
# ['15.1', '20', '15.1', '19', '19.4', '18.1', '13', '20', '19.5', '20', '17', '17.1', '19.3', '12', '19.4', '18.4', '20', '19.1', '18.5', '19', '20', '20', '18.5', '14.2', '18.2', '18', '15.1', '20', '16', '16', '20', '20', '19.1', '15.4', '17.5', '13.5', '20', '5.3', '20', '8', '8', '20', '18.2', '16.3', '20', '20', '', '19.3', '20', '19.5', '19', '19.4', '20', '19.2', '16', '20', '16.1', '14.5', '20']

# %%
r1=[]
for i in runs1:
    r1.append(float(i))
r2=[]
for i in runs2:
    r2.append(float(i))

# %%
o1=[]
for i in overs1:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o1.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o1.append(u)
    elif (len(i)==0):
        o1.append(1)
print(len(o1)) 
print(o1)

o2=[]
for i in overs2:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o2.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o2.append(u)
    elif (len(i)==0):
        o2.append(1)
    elif (len(i)==3):
        j=int(i[0])+int(i[2])*0.1
        o2.append(j)
    elif (len(i)==1):
        o2.append(int(i))
print(len(o2)) 
print(o2)
# Out:
# 59
# [20, 20, 20, 18.4, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19, 19.2, 20, 16.2, 20, 16, 20, 20, 20, 20, 20, 20, 20, 20, 15.2, 20, 11, 20, 20, 20, 20, 20, 20, 1, 20, 20, 20, 20, 20, 20, 20, 18, 20, 20, 20, 20]
# 59
# [15.1, 20, 15.1, 19, 19.4, 18.1, 13, 20, 19.5, 20, 17, 17.1, 19.3, 12, 19.4, 18.4, 20, 19.1, 18.5, 19, 20, 20, 18.5, 14.2, 18.2, 18, 15.1, 20, 16, 16, 20, 20, 19.1, 15.4, 17.5, 13.5, 20, 5.3, 20, 8, 8, 20, 18.2, 16.3, 20, 20, 1, 19.3, 20, 19.5, 19, 19.4, 20, 19.2, 16, 20, 16.1, 14.5, 20]

# %%
runrate1=[]
for i in range(len(o1)):
    runrate1.append((float(r1[i])/float(o1[i]))-(float(r2[i])/float(o2[i])))
runrate1
# Out:
# [5.669536423841059,
#  1.6500000000000004,
#  -2.291721854304636,
#  0.08352402745995491,
#  -0.30670103092783485,
#  -0.9817679558011037,
#  -3.9000000000000004,
#  0.3000000000000007,
#  -0.42820512820512846,
#  3.3,
#  -1.5911764705882359,
#  -1.3201754385964897,
#  -0.4937823834196884,
#  -5.216666666666666,
#  0.39484536082474264,
#  -0.6500000000000012,
#  0.5,
#  1.8942408376963362,
#  -0.827027027027027,
#  -0.6026315789473689,
#  0.14999999999999947,
#  0.45000000000000107,
#  0.9108108108108102,
#  -2.0096367679762794,
#  -0.4155219780219781,
#  -1.0222222222222213,
#  -0.5293925271850215,
#  -0.05000000000000071,
#  0.3125,
#  -1.8125,
#  0.9000000000000004,
#  1.1499999999999986,
#  -0.5246073298429321,
#  -2.20064935064935,
#  0.36428571428571477,
#  -3.9037037037037043,
#  0.5999999999999996,
#  -8.42229394240318,
#  3.25,
#  -1.0227272727272734,
#  0.5750000000000002,
#  1.25,
#  -0.9813186813186823,
#  -1.8524539877300619,
#  0.049999999999998934,
#  0.7000000000000002,
#  0.0,
#  -0.4727979274611389,
#  0.5,
#  -0.37948717948717814,
#  -0.75,
#  -0.32061855670103157,
#  -0.04999999999999982,
#  -0.3583333333333343,
#  -1.0972222222222223,
#  2.0500000000000007,
#  4.196273291925466,
#  -2.4000000000000004,
#  -0.049999999999998934]

# %%
print(len(runrate1))
# Out:
# 59

# %%
runrate2=[]
for i in runrate1:
    runrate2.append(-i)
runrate2
# Out:
# [-5.669536423841059,
#  -1.6500000000000004,
#  2.291721854304636,
#  -0.08352402745995491,
#  0.30670103092783485,
#  0.9817679558011037,
#  3.9000000000000004,
#  -0.3000000000000007,
#  0.42820512820512846,
#  -3.3,
#  1.5911764705882359,
#  1.3201754385964897,
#  0.4937823834196884,
#  5.216666666666666,
#  -0.39484536082474264,
#  0.6500000000000012,
#  -0.5,
#  -1.8942408376963362,
#  0.827027027027027,
#  0.6026315789473689,
#  -0.14999999999999947,
#  -0.45000000000000107,
#  -0.9108108108108102,
#  2.0096367679762794,
#  0.4155219780219781,
#  1.0222222222222213,
#  0.5293925271850215,
#  0.05000000000000071,
#  -0.3125,
#  1.8125,
#  -0.9000000000000004,
#  -1.1499999999999986,
#  0.5246073298429321,
#  2.20064935064935,
#  -0.36428571428571477,
#  3.9037037037037043,
#  -0.5999999999999996,
#  8.42229394240318,
#  -3.25,
#  1.0227272727272734,
#  -0.5750000000000002,
#  -1.25,
#  0.9813186813186823,
#  1.8524539877300619,
#  -0.049999999999998934,
#  -0.7000000000000002,
#  -0.0,
#  0.4727979274611389,
#  -0.5,
#  0.37948717948717814,
#  0.75,
#  0.32061855670103157,
#  0.04999999999999982,
#  0.3583333333333343,
#  1.0972222222222223,
#  -2.0500000000000007,
#  -4.196273291925466,
#  2.4000000000000004,
#  0.049999999999998934]

# %%
rr2008 = pd.DataFrame(runrate1,runrate2)
rr2008.to_csv('rr2008.csv')
