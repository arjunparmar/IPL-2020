# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
def response_await(url):
    response = urlopen(url)
    data = response.read()
    soup = BeautifulSoup(data, 'lxml')
    return soup

# %%
URL="https://www.espncricinfo.com/ipl2010/engine/match/index/series.html?search=Indian Premier League;series=5319"

# %%
content = requests.get(URL)

# %%
soup = BeautifulSoup(content.text, 'html.parser')

# %%
content = requests.get(URL)
soup = BeautifulSoup(content.text, 'html.parser')
row = soup.find_all('span',{"class":"bold"})
row
# Out:
# [<span class="bold">Mar 12, 2010</span>,
#  <span class="bold">161/4 (20 ov)</span>,
#  <span class="bold">150/7 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 11 runs</span>,
#  <span class="bold">Mar 13, 2010</span>,
#  <span class="bold">212/6 (20 ov)</span>,
#  <span class="bold">208/7 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 4 runs</span>,
#  <span class="bold">Mar 13, 2010</span>,
#  <span class="bold">142/9 (20 ov)</span>,
#  <span class="bold">146/5 (19.5/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 5 wickets (with 1 ball remaining)</span>,
#  <span class="bold">Mar 14, 2010</span>,
#  <span class="bold">135/7 (20 ov)</span>,
#  <span class="bold">136/3 (19.2/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 7 wickets (with 4 balls remaining)</span>,
#  <span class="bold">Mar 14, 2010</span>,
#  <span class="bold">190/4 (20 ov)</span>,
#  <span class="bold">159/9 (20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 31 runs</span>,
#  <span class="bold">Mar 15, 2010</span>,
#  <span class="bold">141/6 (20 ov)</span>,
#  <span class="bold">142/4 (17.1/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 6 wickets (with 17 balls remaining)</span>,
#  <span class="bold">Mar 16, 2010</span>,
#  <span class="bold">203/3 (20 ov)</span>,
#  <span class="bold">204/2 (18.5/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 8 wickets (with 7 balls remaining)</span>,
#  <span class="bold">Mar 16, 2010</span>,
#  <span class="bold">164/3 (20 ov)</span>,
#  <span class="bold">109 (19.2/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 55 runs</span>,
#  <span class="bold">Mar 17, 2010</span>,
#  <span class="bold">218/7 (20 ov)</span>,
#  <span class="bold">120 (16.3/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 98 runs</span>,
#  <span class="bold">Mar 18, 2010</span>,
#  <span class="bold">92 (19.5/20 ov)</span>,
#  <span class="bold">93/0 (10.4/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 10 wickets (with 56 balls remaining)</span>,
#  <span class="bold">Mar 19, 2010</span>,
#  <span class="bold">185/6 (20 ov)</span>,
#  <span class="bold">190/5 (19.1/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 5 wickets (with 5 balls remaining)</span>,
#  <span class="bold">Mar 19, 2010</span>,
#  <span class="bold">170/7 (20 ov)</span>,
#  <span class="bold">164/8 (20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 6 runs</span>,
#  <span class="bold">Mar 20, 2010</span>,
#  <span class="bold">168/7 (20 ov)</span>,
#  <span class="bold">134/5 (20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 34 runs</span>,
#  <span class="bold">Mar 20, 2010</span>,
#  <span class="bold">151/9 (20 ov)</span>,
#  <span class="bold">155/3 (19.1/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 7 wickets (with 5 balls remaining)</span>,
#  <span class="bold">Mar 21, 2010</span>,
#  <span class="bold">171/6 (20 ov)</span>,
#  <span class="bold">161/9 (20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 10 runs</span>,
#  <span class="bold">Mar 21, 2010</span>,
#  <span class="bold">136/8 (20 ov)</span>,
#  <span class="bold">136/7 (20 ov)</span>,
#  <span class="bold">Match tied (Kings XI Punjab won the one-over eliminator)</span>,
#  <span class="bold">Mar 22, 2010</span>,
#  <span class="bold">155/3 (20 ov)</span>,
#  <span class="bold">156/3 (18.3/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 7 wickets (with 9 balls remaining)</span>,
#  <span class="bold">Mar 23, 2010</span>,
#  <span class="bold">171/5 (20 ov)</span>,
#  <span class="bold">135/7 (20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 36 runs</span>,
#  <span class="bold">Mar 24, 2010</span>,
#  <span class="bold">183/5 (20 ov)</span>,
#  <span class="bold">152 (19.1/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 31 runs</span>,
#  <span class="bold">Mar 25, 2010</span>,
#  <span class="bold">183/4 (20 ov)</span>,
#  <span class="bold">166/9 (20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 17 runs</span>,
#  <span class="bold">Mar 25, 2010</span>,
#  <span class="bold">180/2 (20 ov)</span>,
#  <span class="bold">181/5 (19/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 5 wickets (with 6 balls remaining)</span>,
#  <span class="bold">Mar 26, 2010</span>,
#  <span class="bold">148/9 (20 ov)</span>,
#  <span class="bold">151/2 (15.4/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 8 wickets (with 26 balls remaining)</span>,
#  <span class="bold">Mar 27, 2010</span>,
#  <span class="bold">183/5 (20 ov)</span>,
#  <span class="bold">144/6 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 39 runs</span>,
#  <span class="bold">Mar 28, 2010</span>,
#  <span class="bold">177/8 (20 ov)</span>,
#  <span class="bold">160/6 (20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 17 runs</span>,
#  <span class="bold">Mar 28, 2010</span>,
#  <span class="bold">172/7 (20 ov)</span>,
#  <span class="bold">131 (17.4/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 41 runs</span>,
#  <span class="bold">Mar 29, 2010</span>,
#  <span class="bold">177/4 (20 ov)</span>,
#  <span class="bold">137/9 (20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 40 runs</span>,
#  <span class="bold">Mar 30, 2010</span>,
#  <span class="bold">163 (20 ov)</span>,
#  <span class="bold">164/6 (19.3/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 4 wickets (with 3 balls remaining)</span>,
#  <span class="bold">Mar 31, 2010</span>,
#  <span class="bold">161/4 (20 ov)</span>,
#  <span class="bold">162/5 (18.5/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 5 wickets (with 7 balls remaining)</span>,
#  <span class="bold">Mar 31, 2010</span>,
#  <span class="bold">188/6 (20 ov)</span>,
#  <span class="bold">121 (17.4/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 67 runs</span>,
#  <span class="bold">Apr 1, 2010</span>,
#  <span class="bold">181/6 (20 ov)</span>,
#  <span class="bold">157/5 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 24 runs</span>,
#  <span class="bold">Apr 2, 2010</span>,
#  <span class="bold">181/5 (20 ov)</span>,
#  <span class="bold">184/4 (19.1/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 6 wickets (with 5 balls remaining)</span>,
#  <span class="bold">Apr 3, 2010</span>,
#  <span class="bold">246/5 (20 ov)</span>,
#  <span class="bold">223/5 (20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 23 runs</span>,
#  <span class="bold">Apr 3, 2010</span>,
#  <span class="bold">178/5 (20 ov)</span>,
#  <span class="bold">115 (18.2/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 63 runs</span>,
#  <span class="bold">Apr 4, 2010</span>,
#  <span class="bold">200/3 (20 ov)</span>,
#  <span class="bold">204/2 (18.2/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 8 wickets (with 10 balls remaining)</span>,
#  <span class="bold">Apr 4, 2010</span>,
#  <span class="bold">184/5 (20 ov)</span>,
#  <span class="bold">147/9 (20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 37 runs</span>,
#  <span class="bold">Apr 5, 2010</span>,
#  <span class="bold">159 (19.5/20 ov)</span>,
#  <span class="bold">157 (19.5/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 2 runs</span>,
#  <span class="bold">Apr 6, 2010</span>,
#  <span class="bold">165/4 (20 ov)</span>,
#  <span class="bold">141/9 (20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 24 runs</span>,
#  <span class="bold">Apr 7, 2010</span>,
#  <span class="bold">153/6 (20 ov)</span>,
#  <span class="bold">157/1 (15/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 9 wickets (with 30 balls remaining)</span>,
#  <span class="bold">Apr 7, 2010</span>,
#  <span class="bold">181/3 (20 ov)</span>,
#  <span class="bold">167/8 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 14 runs</span>,
#  <span class="bold">Apr 8, 2010</span>,
#  <span class="bold">184/6 (20 ov)</span>,
#  <span class="bold">186/3 (19.2/20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 7 wickets (with 4 balls remaining)</span>,
#  <span class="bold">Apr 9, 2010</span>,
#  <span class="bold">154/9 (20 ov)</span>,
#  <span class="bold">158/4 (19.2/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 6 wickets (with 4 balls remaining)</span>,
#  <span class="bold">Apr 10, 2010</span>,
#  <span class="bold">138/8 (20 ov)</span>,
#  <span class="bold">139/4 (19.1/20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 6 wickets (with 5 balls remaining)</span>,
#  <span class="bold">Apr 10, 2010</span>,
#  <span class="bold">160/9 (20 ov)</span>,
#  <span class="bold">162/3 (17.1/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 7 wickets (with 17 balls remaining)</span>,
#  <span class="bold">Apr 11, 2010</span>,
#  <span class="bold">111 (19.4/20 ov)</span>,
#  <span class="bold">112/3 (18.4/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 7 wickets (with 8 balls remaining)</span>,
#  <span class="bold">Apr 11, 2010</span>,
#  <span class="bold">174/5 (20 ov)</span>,
#  <span class="bold">137/8 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 37 runs</span>,
#  <span class="bold">Apr 12, 2010</span>,
#  <span class="bold">151/6 (20 ov)</span>,
#  <span class="bold">138 (19.4/20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 13 runs</span>,
#  <span class="bold">Apr 13, 2010</span>,
#  <span class="bold">183/4 (20 ov)</span>,
#  <span class="bold">144/7 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 39 runs</span>,
#  <span class="bold">Apr 13, 2010</span>,
#  <span class="bold">139/8 (20 ov)</span>,
#  <span class="bold">143/1 (13.3/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 9 wickets (with 39 balls remaining)</span>,
#  <span class="bold">Apr 14, 2010</span>,
#  <span class="bold">130/6 (20 ov)</span>,
#  <span class="bold">132/5 (15.4/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 5 wickets (with 26 balls remaining)</span>,
#  <span class="bold">Apr 15, 2010</span>,
#  <span class="bold">112/9 (20 ov)</span>,
#  <span class="bold">113/4 (18.4/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 6 wickets (with 8 balls remaining)</span>,
#  <span class="bold">Apr 16, 2010</span>,
#  <span class="bold">174/3 (20 ov)</span>,
#  <span class="bold">178/5 (19.1/20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 5 wickets (with 5 balls remaining)</span>,
#  <span class="bold">Apr 17, 2010</span>,
#  <span class="bold">191/4 (20 ov)</span>,
#  <span class="bold">134/9 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 57 runs</span>,
#  <span class="bold">Apr 17, 2010</span>,
#  <span class="bold">132/9 (20 ov)</span>,
#  <span class="bold">133/2 (16.1/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 8 wickets (with 23 balls remaining)</span>,
#  <span class="bold">Apr 18, 2010</span>,
#  <span class="bold">192/3 (20 ov)</span>,
#  <span class="bold">195/4 (19.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 6 wickets (with 2 balls remaining)</span>,
#  <span class="bold">Apr 18, 2010</span>,
#  <span class="bold">145/7 (20 ov)</span>,
#  <span class="bold">134/7 (20 ov)</span>,
#  <span class="bold">Deccan Chargers won by 11 runs</span>,
#  <span class="bold">Apr 19, 2010</span>,
#  <span class="bold">133/8 (20 ov)</span>,
#  <span class="bold">135/1 (17.3/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 9 wickets (with 15 balls remaining)</span>,
#  <span class="bold">Apr 21, 2010</span>,
#  <span class="bold">184/5 (20 ov)</span>,
#  <span class="bold">149/9 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 35 runs</span>,
#  <span class="bold">Apr 22, 2010</span>,
#  <span class="bold">142/7 (20 ov)</span>,
#  <span class="bold">104 (19.2/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 38 runs</span>,
#  <span class="bold">Apr 24, 2010</span>,
#  <span class="bold">82 (18.3/20 ov)</span>,
#  <span class="bold">86/1 (13.5/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 9 wickets (with 37 balls remaining)</span>,
#  <span class="bold">Apr 25, 2010</span>,
#  <span class="bold">168/5 (20 ov)</span>,
#  <span class="bold">146/9 (20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 22 runs</span>]

# %%
x=[]
for i in row:
    x.append(i.text)
x
# Out:
# ['Mar 12, 2010',
#  '161/4 (20 ov)',
#  '150/7 (20 ov)',
#  'Kolkata Knight Riders won by 11 runs',
#  'Mar 13, 2010',
#  '212/6 (20 ov)',
#  '208/7 (20 ov)',
#  'Mumbai Indians won by 4 runs',
#  'Mar 13, 2010',
#  '142/9 (20 ov)',
#  '146/5 (19.5/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 1 ball remaining)',
#  'Mar 14, 2010',
#  '135/7 (20 ov)',
#  '136/3 (19.2/20 ov)',
#  'Kolkata Knight Riders won by 7 wickets (with 4 balls remaining)',
#  'Mar 14, 2010',
#  '190/4 (20 ov)',
#  '159/9 (20 ov)',
#  'Deccan Chargers won by 31 runs',
#  'Mar 15, 2010',
#  '141/6 (20 ov)',
#  '142/4 (17.1/20 ov)',
#  'Delhi Daredevils won by 6 wickets (with 17 balls remaining)',
#  'Mar 16, 2010',
#  '203/3 (20 ov)',
#  '204/2 (18.5/20 ov)',
#  'Royal Challengers Bangalore won by 8 wickets (with 7 balls remaining)',
#  'Mar 16, 2010',
#  '164/3 (20 ov)',
#  '109 (19.2/20 ov)',
#  'Chennai Super Kings won by 55 runs',
#  'Mar 17, 2010',
#  '218/7 (20 ov)',
#  '120 (16.3/20 ov)',
#  'Mumbai Indians won by 98 runs',
#  'Mar 18, 2010',
#  '92 (19.5/20 ov)',
#  '93/0 (10.4/20 ov)',
#  'Royal Challengers Bangalore won by 10 wickets (with 56 balls remaining)',
#  'Mar 19, 2010',
#  '185/6 (20 ov)',
#  '190/5 (19.1/20 ov)',
#  'Chennai Super Kings won by 5 wickets (with 5 balls remaining)',
#  'Mar 19, 2010',
#  '170/7 (20 ov)',
#  '164/8 (20 ov)',
#  'Deccan Chargers won by 6 runs',
#  'Mar 20, 2010',
#  '168/7 (20 ov)',
#  '134/5 (20 ov)',
#  'Rajasthan Royals won by 34 runs',
#  'Mar 20, 2010',
#  '151/9 (20 ov)',
#  '155/3 (19.1/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets (with 5 balls remaining)',
#  'Mar 21, 2010',
#  '171/6 (20 ov)',
#  '161/9 (20 ov)',
#  'Deccan Chargers won by 10 runs',
#  'Mar 21, 2010',
#  '136/8 (20 ov)',
#  '136/7 (20 ov)',
#  'Match tied (Kings XI Punjab won the one-over eliminator)',
#  'Mar 22, 2010',
#  '155/3 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 9 balls remaining)',
#  'Mar 23, 2010',
#  '171/5 (20 ov)',
#  '135/7 (20 ov)',
#  'Royal Challengers Bangalore won by 36 runs',
#  'Mar 24, 2010',
#  '183/5 (20 ov)',
#  '152 (19.1/20 ov)',
#  'Rajasthan Royals won by 31 runs',
#  'Mar 25, 2010',
#  '183/4 (20 ov)',
#  '166/9 (20 ov)',
#  'Delhi Daredevils won by 17 runs',
#  'Mar 25, 2010',
#  '180/2 (20 ov)',
#  '181/5 (19/20 ov)',
#  'Mumbai Indians won by 5 wickets (with 6 balls remaining)',
#  'Mar 26, 2010',
#  '148/9 (20 ov)',
#  '151/2 (15.4/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 26 balls remaining)',
#  'Mar 27, 2010',
#  '183/5 (20 ov)',
#  '144/6 (20 ov)',
#  'Kolkata Knight Riders won by 39 runs',
#  'Mar 28, 2010',
#  '177/8 (20 ov)',
#  '160/6 (20 ov)',
#  'Rajasthan Royals won by 17 runs',
#  'Mar 28, 2010',
#  '172/7 (20 ov)',
#  '131 (17.4/20 ov)',
#  'Mumbai Indians won by 41 runs',
#  'Mar 29, 2010',
#  '177/4 (20 ov)',
#  '137/9 (20 ov)',
#  'Delhi Daredevils won by 40 runs',
#  'Mar 30, 2010',
#  '163 (20 ov)',
#  '164/6 (19.3/20 ov)',
#  'Mumbai Indians won by 4 wickets (with 3 balls remaining)',
#  'Mar 31, 2010',
#  '161/4 (20 ov)',
#  '162/5 (18.5/20 ov)',
#  'Chennai Super Kings won by 5 wickets (with 7 balls remaining)',
#  'Mar 31, 2010',
#  '188/6 (20 ov)',
#  '121 (17.4/20 ov)',
#  'Delhi Daredevils won by 67 runs',
#  'Apr 1, 2010',
#  '181/6 (20 ov)',
#  '157/5 (20 ov)',
#  'Kolkata Knight Riders won by 24 runs',
#  'Apr 2, 2010',
#  '181/5 (20 ov)',
#  '184/4 (19.1/20 ov)',
#  'Royal Challengers Bangalore won by 6 wickets (with 5 balls remaining)',
#  'Apr 3, 2010',
#  '246/5 (20 ov)',
#  '223/5 (20 ov)',
#  'Chennai Super Kings won by 23 runs',
#  'Apr 3, 2010',
#  '178/5 (20 ov)',
#  '115 (18.2/20 ov)',
#  'Mumbai Indians won by 63 runs',
#  'Apr 4, 2010',
#  '200/3 (20 ov)',
#  '204/2 (18.2/20 ov)',
#  'Kings XI Punjab won by 8 wickets (with 10 balls remaining)',
#  'Apr 4, 2010',
#  '184/5 (20 ov)',
#  '147/9 (20 ov)',
#  'Delhi Daredevils won by 37 runs',
#  'Apr 5, 2010',
#  '159 (19.5/20 ov)',
#  '157 (19.5/20 ov)',
#  'Rajasthan Royals won by 2 runs',
#  'Apr 6, 2010',
#  '165/4 (20 ov)',
#  '141/9 (20 ov)',
#  'Chennai Super Kings won by 24 runs',
#  'Apr 7, 2010',
#  '153/6 (20 ov)',
#  '157/1 (15/20 ov)',
#  'Rajasthan Royals won by 9 wickets (with 30 balls remaining)',
#  'Apr 7, 2010',
#  '181/3 (20 ov)',
#  '167/8 (20 ov)',
#  'Kolkata Knight Riders won by 14 runs',
#  'Apr 8, 2010',
#  '184/6 (20 ov)',
#  '186/3 (19.2/20 ov)',
#  'Deccan Chargers won by 7 wickets (with 4 balls remaining)',
#  'Apr 9, 2010',
#  '154/9 (20 ov)',
#  '158/4 (19.2/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 4 balls remaining)',
#  'Apr 10, 2010',
#  '138/8 (20 ov)',
#  '139/4 (19.1/20 ov)',
#  'Deccan Chargers won by 6 wickets (with 5 balls remaining)',
#  'Apr 10, 2010',
#  '160/9 (20 ov)',
#  '162/3 (17.1/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets (with 17 balls remaining)',
#  'Apr 11, 2010',
#  '111 (19.4/20 ov)',
#  '112/3 (18.4/20 ov)',
#  'Kings XI Punjab won by 7 wickets (with 8 balls remaining)',
#  'Apr 11, 2010',
#  '174/5 (20 ov)',
#  '137/8 (20 ov)',
#  'Mumbai Indians won by 37 runs',
#  'Apr 12, 2010',
#  '151/6 (20 ov)',
#  '138 (19.4/20 ov)',
#  'Deccan Chargers won by 13 runs',
#  'Apr 13, 2010',
#  '183/4 (20 ov)',
#  '144/7 (20 ov)',
#  'Mumbai Indians won by 39 runs',
#  'Apr 13, 2010',
#  '139/8 (20 ov)',
#  '143/1 (13.3/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 39 balls remaining)',
#  'Apr 14, 2010',
#  '130/6 (20 ov)',
#  '132/5 (15.4/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 26 balls remaining)',
#  'Apr 15, 2010',
#  '112/9 (20 ov)',
#  '113/4 (18.4/20 ov)',
#  'Delhi Daredevils won by 6 wickets (with 8 balls remaining)',
#  'Apr 16, 2010',
#  '174/3 (20 ov)',
#  '178/5 (19.1/20 ov)',
#  'Deccan Chargers won by 5 wickets (with 5 balls remaining)',
#  'Apr 17, 2010',
#  '191/4 (20 ov)',
#  '134/9 (20 ov)',
#  'Mumbai Indians won by 57 runs',
#  'Apr 17, 2010',
#  '132/9 (20 ov)',
#  '133/2 (16.1/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets (with 23 balls remaining)',
#  'Apr 18, 2010',
#  '192/3 (20 ov)',
#  '195/4 (19.4/20 ov)',
#  'Chennai Super Kings won by 6 wickets (with 2 balls remaining)',
#  'Apr 18, 2010',
#  '145/7 (20 ov)',
#  '134/7 (20 ov)',
#  'Deccan Chargers won by 11 runs',
#  'Apr 19, 2010',
#  '133/8 (20 ov)',
#  '135/1 (17.3/20 ov)',
#  'Kolkata Knight Riders won by 9 wickets (with 15 balls remaining)',
#  'Apr 21, 2010',
#  '184/5 (20 ov)',
#  '149/9 (20 ov)',
#  'Mumbai Indians won by 35 runs',
#  'Apr 22, 2010',
#  '142/7 (20 ov)',
#  '104 (19.2/20 ov)',
#  'Chennai Super Kings won by 38 runs',
#  'Apr 24, 2010',
#  '82 (18.3/20 ov)',
#  '86/1 (13.5/20 ov)',
#  'Royal Challengers Bangalore won by 9 wickets (with 37 balls remaining)',
#  'Apr 25, 2010',
#  '168/5 (20 ov)',
#  '146/9 (20 ov)',
#  'Chennai Super Kings won by 22 runs']

# %%
y=[]
for i in range(0,len(x)):
    if i%4 != 0:
        y.append(x[i])
y
# Out:
# ['161/4 (20 ov)',
#  '150/7 (20 ov)',
#  'Kolkata Knight Riders won by 11 runs',
#  '212/6 (20 ov)',
#  '208/7 (20 ov)',
#  'Mumbai Indians won by 4 runs',
#  '142/9 (20 ov)',
#  '146/5 (19.5/20 ov)',
#  'Delhi Daredevils won by 5 wickets (with 1 ball remaining)',
#  '135/7 (20 ov)',
#  '136/3 (19.2/20 ov)',
#  'Kolkata Knight Riders won by 7 wickets (with 4 balls remaining)',
#  '190/4 (20 ov)',
#  '159/9 (20 ov)',
#  'Deccan Chargers won by 31 runs',
#  '141/6 (20 ov)',
#  '142/4 (17.1/20 ov)',
#  'Delhi Daredevils won by 6 wickets (with 17 balls remaining)',
#  '203/3 (20 ov)',
#  '204/2 (18.5/20 ov)',
#  'Royal Challengers Bangalore won by 8 wickets (with 7 balls remaining)',
#  '164/3 (20 ov)',
#  '109 (19.2/20 ov)',
#  'Chennai Super Kings won by 55 runs',
#  '218/7 (20 ov)',
#  '120 (16.3/20 ov)',
#  'Mumbai Indians won by 98 runs',
#  '92 (19.5/20 ov)',
#  '93/0 (10.4/20 ov)',
#  'Royal Challengers Bangalore won by 10 wickets (with 56 balls remaining)',
#  '185/6 (20 ov)',
#  '190/5 (19.1/20 ov)',
#  'Chennai Super Kings won by 5 wickets (with 5 balls remaining)',
#  '170/7 (20 ov)',
#  '164/8 (20 ov)',
#  'Deccan Chargers won by 6 runs',
#  '168/7 (20 ov)',
#  '134/5 (20 ov)',
#  'Rajasthan Royals won by 34 runs',
#  '151/9 (20 ov)',
#  '155/3 (19.1/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets (with 5 balls remaining)',
#  '171/6 (20 ov)',
#  '161/9 (20 ov)',
#  'Deccan Chargers won by 10 runs',
#  '136/8 (20 ov)',
#  '136/7 (20 ov)',
#  'Match tied (Kings XI Punjab won the one-over eliminator)',
#  '155/3 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  'Mumbai Indians won by 7 wickets (with 9 balls remaining)',
#  '171/5 (20 ov)',
#  '135/7 (20 ov)',
#  'Royal Challengers Bangalore won by 36 runs',
#  '183/5 (20 ov)',
#  '152 (19.1/20 ov)',
#  'Rajasthan Royals won by 31 runs',
#  '183/4 (20 ov)',
#  '166/9 (20 ov)',
#  'Delhi Daredevils won by 17 runs',
#  '180/2 (20 ov)',
#  '181/5 (19/20 ov)',
#  'Mumbai Indians won by 5 wickets (with 6 balls remaining)',
#  '148/9 (20 ov)',
#  '151/2 (15.4/20 ov)',
#  'Rajasthan Royals won by 8 wickets (with 26 balls remaining)',
#  '183/5 (20 ov)',
#  '144/6 (20 ov)',
#  'Kolkata Knight Riders won by 39 runs',
#  '177/8 (20 ov)',
#  '160/6 (20 ov)',
#  'Rajasthan Royals won by 17 runs',
#  '172/7 (20 ov)',
#  '131 (17.4/20 ov)',
#  'Mumbai Indians won by 41 runs',
#  '177/4 (20 ov)',
#  '137/9 (20 ov)',
#  'Delhi Daredevils won by 40 runs',
#  '163 (20 ov)',
#  '164/6 (19.3/20 ov)',
#  'Mumbai Indians won by 4 wickets (with 3 balls remaining)',
#  '161/4 (20 ov)',
#  '162/5 (18.5/20 ov)',
#  'Chennai Super Kings won by 5 wickets (with 7 balls remaining)',
#  '188/6 (20 ov)',
#  '121 (17.4/20 ov)',
#  'Delhi Daredevils won by 67 runs',
#  '181/6 (20 ov)',
#  '157/5 (20 ov)',
#  'Kolkata Knight Riders won by 24 runs',
#  '181/5 (20 ov)',
#  '184/4 (19.1/20 ov)',
#  'Royal Challengers Bangalore won by 6 wickets (with 5 balls remaining)',
#  '246/5 (20 ov)',
#  '223/5 (20 ov)',
#  'Chennai Super Kings won by 23 runs',
#  '178/5 (20 ov)',
#  '115 (18.2/20 ov)',
#  'Mumbai Indians won by 63 runs',
#  '200/3 (20 ov)',
#  '204/2 (18.2/20 ov)',
#  'Kings XI Punjab won by 8 wickets (with 10 balls remaining)',
#  '184/5 (20 ov)',
#  '147/9 (20 ov)',
#  'Delhi Daredevils won by 37 runs',
#  '159 (19.5/20 ov)',
#  '157 (19.5/20 ov)',
#  'Rajasthan Royals won by 2 runs',
#  '165/4 (20 ov)',
#  '141/9 (20 ov)',
#  'Chennai Super Kings won by 24 runs',
#  '153/6 (20 ov)',
#  '157/1 (15/20 ov)',
#  'Rajasthan Royals won by 9 wickets (with 30 balls remaining)',
#  '181/3 (20 ov)',
#  '167/8 (20 ov)',
#  'Kolkata Knight Riders won by 14 runs',
#  '184/6 (20 ov)',
#  '186/3 (19.2/20 ov)',
#  'Deccan Chargers won by 7 wickets (with 4 balls remaining)',
#  '154/9 (20 ov)',
#  '158/4 (19.2/20 ov)',
#  'Kings XI Punjab won by 6 wickets (with 4 balls remaining)',
#  '138/8 (20 ov)',
#  '139/4 (19.1/20 ov)',
#  'Deccan Chargers won by 6 wickets (with 5 balls remaining)',
#  '160/9 (20 ov)',
#  '162/3 (17.1/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets (with 17 balls remaining)',
#  '111 (19.4/20 ov)',
#  '112/3 (18.4/20 ov)',
#  'Kings XI Punjab won by 7 wickets (with 8 balls remaining)',
#  '174/5 (20 ov)',
#  '137/8 (20 ov)',
#  'Mumbai Indians won by 37 runs',
#  '151/6 (20 ov)',
#  '138 (19.4/20 ov)',
#  'Deccan Chargers won by 13 runs',
#  '183/4 (20 ov)',
#  '144/7 (20 ov)',
#  'Mumbai Indians won by 39 runs',
#  '139/8 (20 ov)',
#  '143/1 (13.3/20 ov)',
#  'Chennai Super Kings won by 9 wickets (with 39 balls remaining)',
#  '130/6 (20 ov)',
#  '132/5 (15.4/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets (with 26 balls remaining)',
#  '112/9 (20 ov)',
#  '113/4 (18.4/20 ov)',
#  'Delhi Daredevils won by 6 wickets (with 8 balls remaining)',
#  '174/3 (20 ov)',
#  '178/5 (19.1/20 ov)',
#  'Deccan Chargers won by 5 wickets (with 5 balls remaining)',
#  '191/4 (20 ov)',
#  '134/9 (20 ov)',
#  'Mumbai Indians won by 57 runs',
#  '132/9 (20 ov)',
#  '133/2 (16.1/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets (with 23 balls remaining)',
#  '192/3 (20 ov)',
#  '195/4 (19.4/20 ov)',
#  'Chennai Super Kings won by 6 wickets (with 2 balls remaining)',
#  '145/7 (20 ov)',
#  '134/7 (20 ov)',
#  'Deccan Chargers won by 11 runs',
#  '133/8 (20 ov)',
#  '135/1 (17.3/20 ov)',
#  'Kolkata Knight Riders won by 9 wickets (with 15 balls remaining)',
#  '184/5 (20 ov)',
#  '149/9 (20 ov)',
#  'Mumbai Indians won by 35 runs',
#  '142/7 (20 ov)',
#  '104 (19.2/20 ov)',
#  'Chennai Super Kings won by 38 runs',
#  '82 (18.3/20 ov)',
#  '86/1 (13.5/20 ov)',
#  'Royal Challengers Bangalore won by 9 wickets (with 37 balls remaining)',
#  '168/5 (20 ov)',
#  '146/9 (20 ov)',
#  'Chennai Super Kings won by 22 runs']

# %%
z=[]
for i in range(1,len(y)):
    if i%3 != 0:
        z.append(y[i-1]) 
z
# Out:
# ['161/4 (20 ov)',
#  '150/7 (20 ov)',
#  '212/6 (20 ov)',
#  '208/7 (20 ov)',
#  '142/9 (20 ov)',
#  '146/5 (19.5/20 ov)',
#  '135/7 (20 ov)',
#  '136/3 (19.2/20 ov)',
#  '190/4 (20 ov)',
#  '159/9 (20 ov)',
#  '141/6 (20 ov)',
#  '142/4 (17.1/20 ov)',
#  '203/3 (20 ov)',
#  '204/2 (18.5/20 ov)',
#  '164/3 (20 ov)',
#  '109 (19.2/20 ov)',
#  '218/7 (20 ov)',
#  '120 (16.3/20 ov)',
#  '92 (19.5/20 ov)',
#  '93/0 (10.4/20 ov)',
#  '185/6 (20 ov)',
#  '190/5 (19.1/20 ov)',
#  '170/7 (20 ov)',
#  '164/8 (20 ov)',
#  '168/7 (20 ov)',
#  '134/5 (20 ov)',
#  '151/9 (20 ov)',
#  '155/3 (19.1/20 ov)',
#  '171/6 (20 ov)',
#  '161/9 (20 ov)',
#  '136/8 (20 ov)',
#  '136/7 (20 ov)',
#  '155/3 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  '171/5 (20 ov)',
#  '135/7 (20 ov)',
#  '183/5 (20 ov)',
#  '152 (19.1/20 ov)',
#  '183/4 (20 ov)',
#  '166/9 (20 ov)',
#  '180/2 (20 ov)',
#  '181/5 (19/20 ov)',
#  '148/9 (20 ov)',
#  '151/2 (15.4/20 ov)',
#  '183/5 (20 ov)',
#  '144/6 (20 ov)',
#  '177/8 (20 ov)',
#  '160/6 (20 ov)',
#  '172/7 (20 ov)',
#  '131 (17.4/20 ov)',
#  '177/4 (20 ov)',
#  '137/9 (20 ov)',
#  '163 (20 ov)',
#  '164/6 (19.3/20 ov)',
#  '161/4 (20 ov)',
#  '162/5 (18.5/20 ov)',
#  '188/6 (20 ov)',
#  '121 (17.4/20 ov)',
#  '181/6 (20 ov)',
#  '157/5 (20 ov)',
#  '181/5 (20 ov)',
#  '184/4 (19.1/20 ov)',
#  '246/5 (20 ov)',
#  '223/5 (20 ov)',
#  '178/5 (20 ov)',
#  '115 (18.2/20 ov)',
#  '200/3 (20 ov)',
#  '204/2 (18.2/20 ov)',
#  '184/5 (20 ov)',
#  '147/9 (20 ov)',
#  '159 (19.5/20 ov)',
#  '157 (19.5/20 ov)',
#  '165/4 (20 ov)',
#  '141/9 (20 ov)',
#  '153/6 (20 ov)',
#  '157/1 (15/20 ov)',
#  '181/3 (20 ov)',
#  '167/8 (20 ov)',
#  '184/6 (20 ov)',
#  '186/3 (19.2/20 ov)',
#  '154/9 (20 ov)',
#  '158/4 (19.2/20 ov)',
#  '138/8 (20 ov)',
#  '139/4 (19.1/20 ov)',
#  '160/9 (20 ov)',
#  '162/3 (17.1/20 ov)',
#  '111 (19.4/20 ov)',
#  '112/3 (18.4/20 ov)',
#  '174/5 (20 ov)',
#  '137/8 (20 ov)',
#  '151/6 (20 ov)',
#  '138 (19.4/20 ov)',
#  '183/4 (20 ov)',
#  '144/7 (20 ov)',
#  '139/8 (20 ov)',
#  '143/1 (13.3/20 ov)',
#  '130/6 (20 ov)',
#  '132/5 (15.4/20 ov)',
#  '112/9 (20 ov)',
#  '113/4 (18.4/20 ov)',
#  '174/3 (20 ov)',
#  '178/5 (19.1/20 ov)',
#  '191/4 (20 ov)',
#  '134/9 (20 ov)',
#  '132/9 (20 ov)',
#  '133/2 (16.1/20 ov)',
#  '192/3 (20 ov)',
#  '195/4 (19.4/20 ov)',
#  '145/7 (20 ov)',
#  '134/7 (20 ov)',
#  '133/8 (20 ov)',
#  '135/1 (17.3/20 ov)',
#  '184/5 (20 ov)',
#  '149/9 (20 ov)',
#  '142/7 (20 ov)',
#  '104 (19.2/20 ov)',
#  '82 (18.3/20 ov)',
#  '86/1 (13.5/20 ov)',
#  '168/5 (20 ov)',
#  '146/9 (20 ov)']

# %%
run=[]
for i in z:
    p=[]
    for k in i:
        if k != '/' and k !=' ':
            p.append(k)
        if k == '/' or k ==' ':
            break
    run.append(p)
run
# Out:
# [['1', '6', '1'],
#  ['1', '5', '0'],
#  ['2', '1', '2'],
#  ['2', '0', '8'],
#  ['1', '4', '2'],
#  ['1', '4', '6'],
#  ['1', '3', '5'],
#  ['1', '3', '6'],
#  ['1', '9', '0'],
#  ['1', '5', '9'],
#  ['1', '4', '1'],
#  ['1', '4', '2'],
#  ['2', '0', '3'],
#  ['2', '0', '4'],
#  ['1', '6', '4'],
#  ['1', '0', '9'],
#  ['2', '1', '8'],
#  ['1', '2', '0'],
#  ['9', '2'],
#  ['9', '3'],
#  ['1', '8', '5'],
#  ['1', '9', '0'],
#  ['1', '7', '0'],
#  ['1', '6', '4'],
#  ['1', '6', '8'],
#  ['1', '3', '4'],
#  ['1', '5', '1'],
#  ['1', '5', '5'],
#  ['1', '7', '1'],
#  ['1', '6', '1'],
#  ['1', '3', '6'],
#  ['1', '3', '6'],
#  ['1', '5', '5'],
#  ['1', '5', '6'],
#  ['1', '7', '1'],
#  ['1', '3', '5'],
#  ['1', '8', '3'],
#  ['1', '5', '2'],
#  ['1', '8', '3'],
#  ['1', '6', '6'],
#  ['1', '8', '0'],
#  ['1', '8', '1'],
#  ['1', '4', '8'],
#  ['1', '5', '1'],
#  ['1', '8', '3'],
#  ['1', '4', '4'],
#  ['1', '7', '7'],
#  ['1', '6', '0'],
#  ['1', '7', '2'],
#  ['1', '3', '1'],
#  ['1', '7', '7'],
#  ['1', '3', '7'],
#  ['1', '6', '3'],
#  ['1', '6', '4'],
#  ['1', '6', '1'],
#  ['1', '6', '2'],
#  ['1', '8', '8'],
#  ['1', '2', '1'],
#  ['1', '8', '1'],
#  ['1', '5', '7'],
#  ['1', '8', '1'],
#  ['1', '8', '4'],
#  ['2', '4', '6'],
#  ['2', '2', '3'],
#  ['1', '7', '8'],
#  ['1', '1', '5'],
#  ['2', '0', '0'],
#  ['2', '0', '4'],
#  ['1', '8', '4'],
#  ['1', '4', '7'],
#  ['1', '5', '9'],
#  ['1', '5', '7'],
#  ['1', '6', '5'],
#  ['1', '4', '1'],
#  ['1', '5', '3'],
#  ['1', '5', '7'],
#  ['1', '8', '1'],
#  ['1', '6', '7'],
#  ['1', '8', '4'],
#  ['1', '8', '6'],
#  ['1', '5', '4'],
#  ['1', '5', '8'],
#  ['1', '3', '8'],
#  ['1', '3', '9'],
#  ['1', '6', '0'],
#  ['1', '6', '2'],
#  ['1', '1', '1'],
#  ['1', '1', '2'],
#  ['1', '7', '4'],
#  ['1', '3', '7'],
#  ['1', '5', '1'],
#  ['1', '3', '8'],
#  ['1', '8', '3'],
#  ['1', '4', '4'],
#  ['1', '3', '9'],
#  ['1', '4', '3'],
#  ['1', '3', '0'],
#  ['1', '3', '2'],
#  ['1', '1', '2'],
#  ['1', '1', '3'],
#  ['1', '7', '4'],
#  ['1', '7', '8'],
#  ['1', '9', '1'],
#  ['1', '3', '4'],
#  ['1', '3', '2'],
#  ['1', '3', '3'],
#  ['1', '9', '2'],
#  ['1', '9', '5'],
#  ['1', '4', '5'],
#  ['1', '3', '4'],
#  ['1', '3', '3'],
#  ['1', '3', '5'],
#  ['1', '8', '4'],
#  ['1', '4', '9'],
#  ['1', '4', '2'],
#  ['1', '0', '4'],
#  ['8', '2'],
#  ['8', '6'],
#  ['1', '6', '8'],
#  ['1', '4', '6']]

# %%
runs=[]
for i in run:
    runs.append("".join(i))
runs
# Out:
# ['161',
#  '150',
#  '212',
#  '208',
#  '142',
#  '146',
#  '135',
#  '136',
#  '190',
#  '159',
#  '141',
#  '142',
#  '203',
#  '204',
#  '164',
#  '109',
#  '218',
#  '120',
#  '92',
#  '93',
#  '185',
#  '190',
#  '170',
#  '164',
#  '168',
#  '134',
#  '151',
#  '155',
#  '171',
#  '161',
#  '136',
#  '136',
#  '155',
#  '156',
#  '171',
#  '135',
#  '183',
#  '152',
#  '183',
#  '166',
#  '180',
#  '181',
#  '148',
#  '151',
#  '183',
#  '144',
#  '177',
#  '160',
#  '172',
#  '131',
#  '177',
#  '137',
#  '163',
#  '164',
#  '161',
#  '162',
#  '188',
#  '121',
#  '181',
#  '157',
#  '181',
#  '184',
#  '246',
#  '223',
#  '178',
#  '115',
#  '200',
#  '204',
#  '184',
#  '147',
#  '159',
#  '157',
#  '165',
#  '141',
#  '153',
#  '157',
#  '181',
#  '167',
#  '184',
#  '186',
#  '154',
#  '158',
#  '138',
#  '139',
#  '160',
#  '162',
#  '111',
#  '112',
#  '174',
#  '137',
#  '151',
#  '138',
#  '183',
#  '144',
#  '139',
#  '143',
#  '130',
#  '132',
#  '112',
#  '113',
#  '174',
#  '178',
#  '191',
#  '134',
#  '132',
#  '133',
#  '192',
#  '195',
#  '145',
#  '134',
#  '133',
#  '135',
#  '184',
#  '149',
#  '142',
#  '104',
#  '82',
#  '86',
#  '168',
#  '146']

# %%
for k in range(0,len(runs)):
    if runs[k]=='':
        runs[k]=0
runs
# Out:
# ['161',
#  '150',
#  '212',
#  '208',
#  '142',
#  '146',
#  '135',
#  '136',
#  '190',
#  '159',
#  '141',
#  '142',
#  '203',
#  '204',
#  '164',
#  '109',
#  '218',
#  '120',
#  '92',
#  '93',
#  '185',
#  '190',
#  '170',
#  '164',
#  '168',
#  '134',
#  '151',
#  '155',
#  '171',
#  '161',
#  '136',
#  '136',
#  '155',
#  '156',
#  '171',
#  '135',
#  '183',
#  '152',
#  '183',
#  '166',
#  '180',
#  '181',
#  '148',
#  '151',
#  '183',
#  '144',
#  '177',
#  '160',
#  '172',
#  '131',
#  '177',
#  '137',
#  '163',
#  '164',
#  '161',
#  '162',
#  '188',
#  '121',
#  '181',
#  '157',
#  '181',
#  '184',
#  '246',
#  '223',
#  '178',
#  '115',
#  '200',
#  '204',
#  '184',
#  '147',
#  '159',
#  '157',
#  '165',
#  '141',
#  '153',
#  '157',
#  '181',
#  '167',
#  '184',
#  '186',
#  '154',
#  '158',
#  '138',
#  '139',
#  '160',
#  '162',
#  '111',
#  '112',
#  '174',
#  '137',
#  '151',
#  '138',
#  '183',
#  '144',
#  '139',
#  '143',
#  '130',
#  '132',
#  '112',
#  '113',
#  '174',
#  '178',
#  '191',
#  '134',
#  '132',
#  '133',
#  '192',
#  '195',
#  '145',
#  '134',
#  '133',
#  '135',
#  '184',
#  '149',
#  '142',
#  '104',
#  '82',
#  '86',
#  '168',
#  '146']

# %%
over=[]
for k in z:
    w=[]
    for t in range(len(k)):
        if k[t]=='(':
            w.append(k[t+1])
            if k[t+2] != " ":   
                w.append(k[t+2])
            if k[t+3] != ' ' and k[t+3] != '/' and k[t+3] !='o':
                w.append(k[t+3])
                if k[t+3]=='.':
                    w.append(k[t+4])
            break
    over.append(w)        
over
# Out:
# [['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7', '.', '1'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['2', '0'],
#  ['1', '6', '.', '3'],
#  ['1', '9', '.', '5'],
#  ['1', '0', '.', '4'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9'],
#  ['2', '0'],
#  ['1', '5', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '7', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['1', '7', '.', '1'],
#  ['1', '9', '.', '4'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '3', '.', '3'],
#  ['2', '0'],
#  ['1', '5', '.', '4'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '6', '.', '1'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['1', '8', '.', '3'],
#  ['1', '3', '.', '5'],
#  ['2', '0'],
#  ['2', '0']]

# %%
overs=[]
for i in over:
    overs.append("".join(i))
    
overs
# Out:
# ['20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '19.5',
#  '20',
#  '19.2',
#  '20',
#  '20',
#  '20',
#  '17.1',
#  '20',
#  '18.5',
#  '20',
#  '19.2',
#  '20',
#  '16.3',
#  '19.5',
#  '10.4',
#  '20',
#  '19.1',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '19.1',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '18.3',
#  '20',
#  '20',
#  '20',
#  '19.1',
#  '20',
#  '20',
#  '20',
#  '19',
#  '20',
#  '15.4',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '17.4',
#  '20',
#  '20',
#  '20',
#  '19.3',
#  '20',
#  '18.5',
#  '20',
#  '17.4',
#  '20',
#  '20',
#  '20',
#  '19.1',
#  '20',
#  '20',
#  '20',
#  '18.2',
#  '20',
#  '18.2',
#  '20',
#  '20',
#  '19.5',
#  '19.5',
#  '20',
#  '20',
#  '20',
#  '15',
#  '20',
#  '20',
#  '20',
#  '19.2',
#  '20',
#  '19.2',
#  '20',
#  '19.1',
#  '20',
#  '17.1',
#  '19.4',
#  '18.4',
#  '20',
#  '20',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '13.3',
#  '20',
#  '15.4',
#  '20',
#  '18.4',
#  '20',
#  '19.1',
#  '20',
#  '20',
#  '20',
#  '16.1',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '17.3',
#  '20',
#  '20',
#  '20',
#  '19.2',
#  '18.3',
#  '13.5',
#  '20',
#  '20']

# %%
runs1=[]
runs2=[]
for i in range(len(runs)):
    if i%2 ==0:
        
        runs1.append(runs[i])
    else:
        runs2.append(runs[i])
overs1=[]
overs2=[]
for i in range(len(overs)):
    if i%2 ==0:
        
        overs1.append(overs[i])
    else:
        overs2.append(overs[i]) 
print(len(runs1))
print(len(runs2))
print(len(overs1))
print(len(overs2))
# Out:
# 60
# 60
# 60
# 60

# %%
r1=[]
for i in runs1:
    r1.append(float(i))
r2=[]
for i in runs2:
    r2.append(float(i))

# %%
o1=[]
for i in overs1:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o1.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o1.append(u)
    elif (len(i)==0):
        o1.append(1)
print(len(o1)) 
print(o1)

o2=[]
for i in overs2:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o2.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o2.append(u)
    elif (len(i)==0):
        o2.append(1)
    elif (len(i)==3):
        j=int(i[0])+int(i[2])*0.1
        o2.append(j)
    elif (len(i)==1):
        o2.append(int(i))
print(len(o2)) 
print(o2)
# Out:
# 60
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 19.5, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19.5, 20, 20, 20, 20, 20, 20, 20, 19.4, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 18.3, 20]
# 60
# [20, 20, 19.5, 19.2, 20, 17.1, 18.5, 19.2, 16.3, 10.4, 19.1, 20, 20, 19.1, 20, 20, 18.3, 20, 19.1, 20, 19, 15.4, 20, 20, 17.4, 20, 19.3, 18.5, 17.4, 20, 19.1, 20, 18.2, 18.2, 20, 19.5, 20, 15, 20, 19.2, 19.2, 19.1, 17.1, 18.4, 20, 19.4, 20, 13.3, 15.4, 18.4, 19.1, 20, 16.1, 19.4, 20, 17.3, 20, 19.2, 13.5, 20]

# %%
runrate1=[]
for i in range(len(o1)):
    runrate1.append((float(r1[i])/float(o1[i]))-(float(r2[i])/float(o2[i])))
runrate1
# Out:
# [0.5500000000000007,
#  0.1999999999999993,
#  -0.3871794871794876,
#  -0.3333333333333339,
#  1.5499999999999998,
#  -1.254093567251462,
#  -0.877027027027026,
#  2.5229166666666654,
#  3.538036809815952,
#  -4.224358974358974,
#  -0.6976439790575917,
#  0.3000000000000007,
#  1.7000000000000002,
#  -0.5651832460732988,
#  0.5,
#  0.0,
#  -0.774590163934425,
#  1.8000000000000007,
#  1.1918848167539275,
#  0.8499999999999996,
#  -0.526315789473685,
#  -2.405194805194805,
#  1.9500000000000002,
#  0.8499999999999996,
#  1.0712643678160907,
#  2.0,
#  -0.3474093264248701,
#  -0.7067567567567554,
#  2.4459770114942527,
#  1.200000000000001,
#  -0.5835078534031393,
#  1.1500000000000004,
#  2.581318681318681,
#  -1.2087912087912098,
#  1.8499999999999996,
#  0.1025641025641022,
#  1.2000000000000002,
#  -2.8166666666666664,
#  0.7000000000000011,
#  -0.4875000000000007,
#  -0.5291666666666677,
#  -0.3774869109947634,
#  -1.473684210526315,
#  -0.36530703720304825,
#  1.8499999999999996,
#  0.43659793814432923,
#  1.9500000000000002,
#  -3.8018796992481194,
#  -2.071428571428571,
#  -0.5413043478260882,
#  -0.6193717277486908,
#  2.8500000000000005,
#  -1.660869565217391,
#  -0.45154639175257927,
#  0.5499999999999998,
#  -1.1534682080924847,
#  1.7499999999999991,
#  1.6833333333333327,
#  -1.8894960534304799,
#  1.1000000000000005]

# %%
runrate2=[]
for i in runrate1:
    runrate2.append(-i)
runrate2
# Out:
# [-0.5500000000000007,
#  -0.1999999999999993,
#  0.3871794871794876,
#  0.3333333333333339,
#  -1.5499999999999998,
#  1.254093567251462,
#  0.877027027027026,
#  -2.5229166666666654,
#  -3.538036809815952,
#  4.224358974358974,
#  0.6976439790575917,
#  -0.3000000000000007,
#  -1.7000000000000002,
#  0.5651832460732988,
#  -0.5,
#  -0.0,
#  0.774590163934425,
#  -1.8000000000000007,
#  -1.1918848167539275,
#  -0.8499999999999996,
#  0.526315789473685,
#  2.405194805194805,
#  -1.9500000000000002,
#  -0.8499999999999996,
#  -1.0712643678160907,
#  -2.0,
#  0.3474093264248701,
#  0.7067567567567554,
#  -2.4459770114942527,
#  -1.200000000000001,
#  0.5835078534031393,
#  -1.1500000000000004,
#  -2.581318681318681,
#  1.2087912087912098,
#  -1.8499999999999996,
#  -0.1025641025641022,
#  -1.2000000000000002,
#  2.8166666666666664,
#  -0.7000000000000011,
#  0.4875000000000007,
#  0.5291666666666677,
#  0.3774869109947634,
#  1.473684210526315,
#  0.36530703720304825,
#  -1.8499999999999996,
#  -0.43659793814432923,
#  -1.9500000000000002,
#  3.8018796992481194,
#  2.071428571428571,
#  0.5413043478260882,
#  0.6193717277486908,
#  -2.8500000000000005,
#  1.660869565217391,
#  0.45154639175257927,
#  -0.5499999999999998,
#  1.1534682080924847,
#  -1.7499999999999991,
#  -1.6833333333333327,
#  1.8894960534304799,
#  -1.1000000000000005]

# %%
rr2010 = pd.DataFrame(runrate1,runrate2)
rr2010.to_csv('rr2010.csv')
