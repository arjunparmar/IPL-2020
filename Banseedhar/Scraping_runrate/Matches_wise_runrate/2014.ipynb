# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
def response_await(url):
    response = urlopen(url)
    data = response.read()
    soup = BeautifulSoup(data, 'lxml')
    return soup

# %%
URL="https://www.espncricinfo.com/indian-premier-league-2014/engine/match/index/series.html?search=Indian Premier League;series=8827"

# %%
content = requests.get(URL)

# %%
soup = BeautifulSoup(content.text, 'html.parser')

# %%
content = requests.get(URL)
soup = BeautifulSoup(content.text, 'html.parser')
row = soup.find_all('span',{"class":"bold"})
row
# Out:
# [<span class="bold">Apr 16, 2014</span>,
#  <span class="bold">163/5 (20 ov)</span>,
#  <span class="bold">122/7 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 41 runs</span>,
#  <span class="bold">Apr 17, 2014</span>,
#  <span class="bold">145/4 (20 ov)</span>,
#  <span class="bold">146/2 (16.4/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 8 wickets</span>,
#  <span class="bold">Apr 18, 2014</span>,
#  <span class="bold">205/4 (20 ov)</span>,
#  <span class="bold">206/4 (18.5/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 6 wickets</span>,
#  <span class="bold">Apr 18, 2014</span>,
#  <span class="bold">133/6 (20 ov)</span>,
#  <span class="bold">135/6 (19.3/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 4 wickets</span>,
#  <span class="bold">Apr 19, 2014</span>,
#  <span class="bold">115/9 (20 ov)</span>,
#  <span class="bold">116/3 (17.3/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 7 wickets</span>,
#  <span class="bold">Apr 19, 2014</span>,
#  <span class="bold">166/5 (20 ov)</span>,
#  <span class="bold">167/6 (19.3/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 4 wickets</span>,
#  <span class="bold">Apr 20, 2014</span>,
#  <span class="bold">191/5 (20 ov)</span>,
#  <span class="bold">193/3 (18.4/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 7 wickets</span>,
#  <span class="bold">Apr 21, 2014</span>,
#  <span class="bold">177/7 (20 ov)</span>,
#  <span class="bold">84 (15.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 93 runs</span>,
#  <span class="bold">Apr 22, 2014</span>,
#  <span class="bold">193/6 (20 ov)</span>,
#  <span class="bold">121 (19.2/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 72 runs</span>,
#  <span class="bold">Apr 23, 2014</span>,
#  <span class="bold">140/6 (20 ov)</span>,
#  <span class="bold">133 (19.5/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 7 runs</span>,
#  <span class="bold">Apr 24, 2014</span>,
#  <span class="bold">150/7 (20 ov)</span>,
#  <span class="bold">148/5 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 2 runs</span>,
#  <span class="bold">Apr 25, 2014</span>,
#  <span class="bold">184/1 (20 ov)</span>,
#  <span class="bold">180/4 (20 ov)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 4 runs</span>,
#  <span class="bold">Apr 25, 2014</span>,
#  <span class="bold">141/7 (20 ov)</span>,
#  <span class="bold">142/3 (19/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 7 wickets</span>,
#  <span class="bold">Apr 26, 2014</span>,
#  <span class="bold">70 (15/20 ov)</span>,
#  <span class="bold">71/4 (13/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 6 wickets</span>,
#  <span class="bold">Apr 26, 2014</span>,
#  <span class="bold">132/9 (20 ov)</span>,
#  <span class="bold">109 (18.2/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 23 runs</span>,
#  <span class="bold">Apr 27, 2014</span>,
#  <span class="bold">125/6 (20 ov)</span>,
#  <span class="bold">126/4 (18.5/20 ov)</span>,
#  <span class="bold">Delhi Daredevils won by 6 wickets</span>,
#  <span class="bold">Apr 27, 2014</span>,
#  <span class="bold">145/5 (20 ov)</span>,
#  <span class="bold">146/5 (19.3/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 5 wickets</span>,
#  <span class="bold">Apr 28, 2014</span>,
#  <span class="bold">124/8 (20 ov)</span>,
#  <span class="bold">127/5 (18.5/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 5 wickets</span>,
#  <span class="bold">Apr 29, 2014</span>,
#  <span class="bold">152/5 (20 ov)</span>,
#  <span class="bold">152/8 (20 ov)</span>,
#  <span class="bold">Match tied (Rajasthan Royals won the one-over eliminator)</span>,
#  <span class="bold">Apr 30, 2014</span>,
#  <span class="bold">172/5 (20 ov)</span>,
#  <span class="bold">157/7 (20 ov)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 15 runs</span>,
#  <span class="bold">May 2, 2014</span>,
#  <span class="bold">148/3 (17 ov)</span>,
#  <span class="bold">114/9 (17 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 34 runs</span>,
#  <span class="bold">May 3, 2014</span>,
#  <span class="bold">168/5 (20 ov)</span>,
#  <span class="bold">170/5 (19.1/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 5 wickets</span>,
#  <span class="bold">May 3, 2014</span>,
#  <span class="bold">152/5 (20 ov)</span>,
#  <span class="bold">156/3 (18.3/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 7 wickets</span>,
#  <span class="bold">May 4, 2014</span>,
#  <span class="bold">155/6 (20 ov)</span>,
#  <span class="bold">158/6 (19.5/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 4 wickets</span>,
#  <span class="bold">May 5, 2014</span>,
#  <span class="bold">170/6 (20 ov)</span>,
#  <span class="bold">160/6 (20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 10 runs</span>,
#  <span class="bold">May 5, 2014</span>,
#  <span class="bold">178/5 (20 ov)</span>,
#  <span class="bold">181/2 (19.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 8 wickets</span>,
#  <span class="bold">May 6, 2014</span>,
#  <span class="bold">187/5 (20 ov)</span>,
#  <span class="bold">168/8 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 19 runs</span>,
#  <span class="bold">May 7, 2014</span>,
#  <span class="bold">160/5 (20 ov)</span>,
#  <span class="bold">161/2 (18.2/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 8 wickets</span>,
#  <span class="bold">May 7, 2014</span>,
#  <span class="bold">231/4 (20 ov)</span>,
#  <span class="bold">187/6 (20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 44 runs</span>,
#  <span class="bold">May 8, 2014</span>,
#  <span class="bold">134/9 (20 ov)</span>,
#  <span class="bold">102 (19.5/20 ov)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 32 runs</span>,
#  <span class="bold">May 9, 2014</span>,
#  <span class="bold">198/8 (20 ov)</span>,
#  <span class="bold">166/9 (20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 32 runs</span>,
#  <span class="bold">May 10, 2014</span>,
#  <span class="bold">143/7 (20 ov)</span>,
#  <span class="bold">44/2 (4.2/5 ov, target: 43)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 8 wickets (D/L method)</span>,
#  <span class="bold">May 10, 2014</span>,
#  <span class="bold">157/6 (20 ov)</span>,
#  <span class="bold">160/6 (19.3/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 4 wickets</span>,
#  <span class="bold">May 11, 2014</span>,
#  <span class="bold">149/8 (20 ov)</span>,
#  <span class="bold">150/1 (18/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 9 wickets</span>,
#  <span class="bold">May 11, 2014</span>,
#  <span class="bold">190/5 (20 ov)</span>,
#  <span class="bold">191/5 (18.5/20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 5 wickets</span>,
#  <span class="bold">May 12, 2014</span>,
#  <span class="bold">157/3 (20 ov)</span>,
#  <span class="bold">160/3 (18.4/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 7 wickets</span>,
#  <span class="bold">May 13, 2014</span>,
#  <span class="bold">148/8 (20 ov)</span>,
#  <span class="bold">149/5 (19.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 5 wickets</span>,
#  <span class="bold">May 13, 2014</span>,
#  <span class="bold">186/4 (20 ov)</span>,
#  <span class="bold">170/7 (20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 16 runs</span>,
#  <span class="bold">May 14, 2014</span>,
#  <span class="bold">205/5 (20 ov)</span>,
#  <span class="bold">211/4 (18.4/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 6 wickets</span>,
#  <span class="bold">May 14, 2014</span>,
#  <span class="bold">141/5 (20 ov)</span>,
#  <span class="bold">142/4 (18.4/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 6 wickets</span>,
#  <span class="bold">May 15, 2014</span>,
#  <span class="bold">201/6 (20 ov)</span>,
#  <span class="bold">139/9 (20 ov)</span>,
#  <span class="bold">Rajasthan Royals won by 62 runs</span>,
#  <span class="bold">May 18, 2014</span>,
#  <span class="bold">138/4 (20 ov)</span>,
#  <span class="bold">142/5 (19.5/20 ov)</span>,
#  <span class="bold">Royal Challengers Bangalore won by 5 wickets</span>,
#  <span class="bold">May 18, 2014</span>,
#  <span class="bold">142/8 (20 ov)</span>,
#  <span class="bold">146/3 (19.4/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 7 wickets</span>,
#  <span class="bold">May 19, 2014</span>,
#  <span class="bold">178/3 (20 ov)</span>,
#  <span class="bold">153/8 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 25 runs</span>,
#  <span class="bold">May 19, 2014</span>,
#  <span class="bold">164/7 (20 ov)</span>,
#  <span class="bold">165/6 (19.4/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 4 wickets</span>,
#  <span class="bold">May 20, 2014</span>,
#  <span class="bold">160/6 (20 ov)</span>,
#  <span class="bold">161/3 (19.4/20 ov)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 7 wickets</span>,
#  <span class="bold">May 20, 2014</span>,
#  <span class="bold">154/4 (20 ov)</span>,
#  <span class="bold">156/2 (18/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 8 wickets</span>,
#  <span class="bold">May 21, 2014</span>,
#  <span class="bold">156/8 (20 ov)</span>,
#  <span class="bold">159/3 (19/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 7 wickets</span>,
#  <span class="bold">May 22, 2014</span>,
#  <span class="bold">195/4 (20 ov)</span>,
#  <span class="bold">165/5 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 30 runs</span>,
#  <span class="bold">May 22, 2014</span>,
#  <span class="bold">185/3 (20 ov)</span>,
#  <span class="bold">189/4 (19.4/20 ov)</span>,
#  <span class="bold">Sunrisers Hyderabad won by 6 wickets</span>,
#  <span class="bold">May 23, 2014</span>,
#  <span class="bold">173 (19.3/20 ov)</span>,
#  <span class="bold">158/4 (20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 15 runs</span>,
#  <span class="bold">May 23, 2014</span>,
#  <span class="bold">179/4 (20 ov)</span>,
#  <span class="bold">163/8 (20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 16 runs</span>,
#  <span class="bold">May 24, 2014</span>,
#  <span class="bold">154/6 (20 ov)</span>,
#  <span class="bold">160/2 (17.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 8 wickets</span>,
#  <span class="bold">May 24, 2014</span>,
#  <span class="bold">160/7 (20 ov)</span>,
#  <span class="bold">161/6 (14.2/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 4 wickets</span>,
#  <span class="bold">May 25, 2014</span>,
#  <span class="bold">115 (18.1/20 ov)</span>,
#  <span class="bold">119/3 (13.5/20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 7 wickets</span>,
#  <span class="bold">May 25, 2014</span>,
#  <span class="bold">189/4 (20 ov)</span>,
#  <span class="bold">195/5 (14.4/20 ov)</span>,
#  <span class="bold">Mumbai Indians won by 5 wickets</span>,
#  <span class="bold">May 27-28, 2014</span>,
#  <span class="bold">163/8 (20 ov)</span>,
#  <span class="bold">135/8 (20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 28 runs</span>,
#  <span class="bold">May 28, 2014</span>,
#  <span class="bold">173/8 (20 ov)</span>,
#  <span class="bold">176/3 (18.4/20 ov)</span>,
#  <span class="bold">Chennai Super Kings won by 7 wickets</span>,
#  <span class="bold">May 30, 2014</span>,
#  <span class="bold">226/6 (20 ov)</span>,
#  <span class="bold">202/7 (20 ov)</span>,
#  <span class="bold">Kings XI Punjab won by 24 runs</span>,
#  <span class="bold">Jun 1, 2014</span>,
#  <span class="bold">199/4 (20 ov)</span>,
#  <span class="bold">200/7 (19.3/20 ov)</span>,
#  <span class="bold">Kolkata Knight Riders won by 3 wickets</span>]

# %%
x=[]
for i in row:
    x.append(i.text)
x
# Out:
# ['Apr 16, 2014',
#  '163/5 (20 ov)',
#  '122/7 (20 ov)',
#  'Kolkata Knight Riders won by 41 runs',
#  'Apr 17, 2014',
#  '145/4 (20 ov)',
#  '146/2 (16.4/20 ov)',
#  'Royal Challengers Bangalore won by 8 wickets',
#  'Apr 18, 2014',
#  '205/4 (20 ov)',
#  '206/4 (18.5/20 ov)',
#  'Kings XI Punjab won by 6 wickets',
#  'Apr 18, 2014',
#  '133/6 (20 ov)',
#  '135/6 (19.3/20 ov)',
#  'Rajasthan Royals won by 4 wickets',
#  'Apr 19, 2014',
#  '115/9 (20 ov)',
#  '116/3 (17.3/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets',
#  'Apr 19, 2014',
#  '166/5 (20 ov)',
#  '167/6 (19.3/20 ov)',
#  'Delhi Daredevils won by 4 wickets',
#  'Apr 20, 2014',
#  '191/5 (20 ov)',
#  '193/3 (18.4/20 ov)',
#  'Kings XI Punjab won by 7 wickets',
#  'Apr 21, 2014',
#  '177/7 (20 ov)',
#  '84 (15.4/20 ov)',
#  'Chennai Super Kings won by 93 runs',
#  'Apr 22, 2014',
#  '193/6 (20 ov)',
#  '121 (19.2/20 ov)',
#  'Kings XI Punjab won by 72 runs',
#  'Apr 23, 2014',
#  '140/6 (20 ov)',
#  '133 (19.5/20 ov)',
#  'Chennai Super Kings won by 7 runs',
#  'Apr 24, 2014',
#  '150/7 (20 ov)',
#  '148/5 (20 ov)',
#  'Kolkata Knight Riders won by 2 runs',
#  'Apr 25, 2014',
#  '184/1 (20 ov)',
#  '180/4 (20 ov)',
#  'Sunrisers Hyderabad won by 4 runs',
#  'Apr 25, 2014',
#  '141/7 (20 ov)',
#  '142/3 (19/20 ov)',
#  'Chennai Super Kings won by 7 wickets',
#  'Apr 26, 2014',
#  '70 (15/20 ov)',
#  '71/4 (13/20 ov)',
#  'Rajasthan Royals won by 6 wickets',
#  'Apr 26, 2014',
#  '132/9 (20 ov)',
#  '109 (18.2/20 ov)',
#  'Kings XI Punjab won by 23 runs',
#  'Apr 27, 2014',
#  '125/6 (20 ov)',
#  '126/4 (18.5/20 ov)',
#  'Delhi Daredevils won by 6 wickets',
#  'Apr 27, 2014',
#  '145/5 (20 ov)',
#  '146/5 (19.3/20 ov)',
#  'Chennai Super Kings won by 5 wickets',
#  'Apr 28, 2014',
#  '124/8 (20 ov)',
#  '127/5 (18.5/20 ov)',
#  'Kings XI Punjab won by 5 wickets',
#  'Apr 29, 2014',
#  '152/5 (20 ov)',
#  '152/8 (20 ov)',
#  'Match tied (Rajasthan Royals won the one-over eliminator)',
#  'Apr 30, 2014',
#  '172/5 (20 ov)',
#  '157/7 (20 ov)',
#  'Sunrisers Hyderabad won by 15 runs',
#  'May 2, 2014',
#  '148/3 (17 ov)',
#  '114/9 (17 ov)',
#  'Chennai Super Kings won by 34 runs',
#  'May 3, 2014',
#  '168/5 (20 ov)',
#  '170/5 (19.1/20 ov)',
#  'Mumbai Indians won by 5 wickets',
#  'May 3, 2014',
#  '152/5 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  'Rajasthan Royals won by 7 wickets',
#  'May 4, 2014',
#  '155/6 (20 ov)',
#  '158/6 (19.5/20 ov)',
#  'Royal Challengers Bangalore won by 4 wickets',
#  'May 5, 2014',
#  '170/6 (20 ov)',
#  '160/6 (20 ov)',
#  'Rajasthan Royals won by 10 runs',
#  'May 5, 2014',
#  '178/5 (20 ov)',
#  '181/2 (19.4/20 ov)',
#  'Chennai Super Kings won by 8 wickets',
#  'May 6, 2014',
#  '187/5 (20 ov)',
#  '168/8 (20 ov)',
#  'Mumbai Indians won by 19 runs',
#  'May 7, 2014',
#  '160/5 (20 ov)',
#  '161/2 (18.2/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets',
#  'May 7, 2014',
#  '231/4 (20 ov)',
#  '187/6 (20 ov)',
#  'Kings XI Punjab won by 44 runs',
#  'May 8, 2014',
#  '134/9 (20 ov)',
#  '102 (19.5/20 ov)',
#  'Sunrisers Hyderabad won by 32 runs',
#  'May 9, 2014',
#  '198/8 (20 ov)',
#  '166/9 (20 ov)',
#  'Kings XI Punjab won by 32 runs',
#  'May 10, 2014',
#  '143/7 (20 ov)',
#  '44/2 (4.2/5 ov, target: 43)',
#  'Sunrisers Hyderabad won by 8 wickets (D/L method)',
#  'May 10, 2014',
#  '157/6 (20 ov)',
#  '160/6 (19.3/20 ov)',
#  'Chennai Super Kings won by 4 wickets',
#  'May 11, 2014',
#  '149/8 (20 ov)',
#  '150/1 (18/20 ov)',
#  'Kolkata Knight Riders won by 9 wickets',
#  'May 11, 2014',
#  '190/5 (20 ov)',
#  '191/5 (18.5/20 ov)',
#  'Rajasthan Royals won by 5 wickets',
#  'May 12, 2014',
#  '157/3 (20 ov)',
#  '160/3 (18.4/20 ov)',
#  'Mumbai Indians won by 7 wickets',
#  'May 13, 2014',
#  '148/8 (20 ov)',
#  '149/5 (19.4/20 ov)',
#  'Chennai Super Kings won by 5 wickets',
#  'May 13, 2014',
#  '186/4 (20 ov)',
#  '170/7 (20 ov)',
#  'Royal Challengers Bangalore won by 16 runs',
#  'May 14, 2014',
#  '205/5 (20 ov)',
#  '211/4 (18.4/20 ov)',
#  'Kings XI Punjab won by 6 wickets',
#  'May 14, 2014',
#  '141/5 (20 ov)',
#  '142/4 (18.4/20 ov)',
#  'Kolkata Knight Riders won by 6 wickets',
#  'May 15, 2014',
#  '201/6 (20 ov)',
#  '139/9 (20 ov)',
#  'Rajasthan Royals won by 62 runs',
#  'May 18, 2014',
#  '138/4 (20 ov)',
#  '142/5 (19.5/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets',
#  'May 18, 2014',
#  '142/8 (20 ov)',
#  '146/3 (19.4/20 ov)',
#  'Kolkata Knight Riders won by 7 wickets',
#  'May 19, 2014',
#  '178/3 (20 ov)',
#  '153/8 (20 ov)',
#  'Mumbai Indians won by 25 runs',
#  'May 19, 2014',
#  '164/7 (20 ov)',
#  '165/6 (19.4/20 ov)',
#  'Kings XI Punjab won by 4 wickets',
#  'May 20, 2014',
#  '160/6 (20 ov)',
#  '161/3 (19.4/20 ov)',
#  'Sunrisers Hyderabad won by 7 wickets',
#  'May 20, 2014',
#  '154/4 (20 ov)',
#  '156/2 (18/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets',
#  'May 21, 2014',
#  '156/8 (20 ov)',
#  '159/3 (19/20 ov)',
#  'Mumbai Indians won by 7 wickets',
#  'May 22, 2014',
#  '195/4 (20 ov)',
#  '165/5 (20 ov)',
#  'Kolkata Knight Riders won by 30 runs',
#  'May 22, 2014',
#  '185/3 (20 ov)',
#  '189/4 (19.4/20 ov)',
#  'Sunrisers Hyderabad won by 6 wickets',
#  'May 23, 2014',
#  '173 (19.3/20 ov)',
#  '158/4 (20 ov)',
#  'Mumbai Indians won by 15 runs',
#  'May 23, 2014',
#  '179/4 (20 ov)',
#  '163/8 (20 ov)',
#  'Kings XI Punjab won by 16 runs',
#  'May 24, 2014',
#  '154/6 (20 ov)',
#  '160/2 (17.4/20 ov)',
#  'Chennai Super Kings won by 8 wickets',
#  'May 24, 2014',
#  '160/7 (20 ov)',
#  '161/6 (14.2/20 ov)',
#  'Kolkata Knight Riders won by 4 wickets',
#  'May 25, 2014',
#  '115 (18.1/20 ov)',
#  '119/3 (13.5/20 ov)',
#  'Kings XI Punjab won by 7 wickets',
#  'May 25, 2014',
#  '189/4 (20 ov)',
#  '195/5 (14.4/20 ov)',
#  'Mumbai Indians won by 5 wickets',
#  'May 27-28, 2014',
#  '163/8 (20 ov)',
#  '135/8 (20 ov)',
#  'Kolkata Knight Riders won by 28 runs',
#  'May 28, 2014',
#  '173/8 (20 ov)',
#  '176/3 (18.4/20 ov)',
#  'Chennai Super Kings won by 7 wickets',
#  'May 30, 2014',
#  '226/6 (20 ov)',
#  '202/7 (20 ov)',
#  'Kings XI Punjab won by 24 runs',
#  'Jun 1, 2014',
#  '199/4 (20 ov)',
#  '200/7 (19.3/20 ov)',
#  'Kolkata Knight Riders won by 3 wickets']

# %%
y=[]
for i in range(0,len(x)):
    if i%4 != 0:
        y.append(x[i])
y
# Out:
# ['163/5 (20 ov)',
#  '122/7 (20 ov)',
#  'Kolkata Knight Riders won by 41 runs',
#  '145/4 (20 ov)',
#  '146/2 (16.4/20 ov)',
#  'Royal Challengers Bangalore won by 8 wickets',
#  '205/4 (20 ov)',
#  '206/4 (18.5/20 ov)',
#  'Kings XI Punjab won by 6 wickets',
#  '133/6 (20 ov)',
#  '135/6 (19.3/20 ov)',
#  'Rajasthan Royals won by 4 wickets',
#  '115/9 (20 ov)',
#  '116/3 (17.3/20 ov)',
#  'Royal Challengers Bangalore won by 7 wickets',
#  '166/5 (20 ov)',
#  '167/6 (19.3/20 ov)',
#  'Delhi Daredevils won by 4 wickets',
#  '191/5 (20 ov)',
#  '193/3 (18.4/20 ov)',
#  'Kings XI Punjab won by 7 wickets',
#  '177/7 (20 ov)',
#  '84 (15.4/20 ov)',
#  'Chennai Super Kings won by 93 runs',
#  '193/6 (20 ov)',
#  '121 (19.2/20 ov)',
#  'Kings XI Punjab won by 72 runs',
#  '140/6 (20 ov)',
#  '133 (19.5/20 ov)',
#  'Chennai Super Kings won by 7 runs',
#  '150/7 (20 ov)',
#  '148/5 (20 ov)',
#  'Kolkata Knight Riders won by 2 runs',
#  '184/1 (20 ov)',
#  '180/4 (20 ov)',
#  'Sunrisers Hyderabad won by 4 runs',
#  '141/7 (20 ov)',
#  '142/3 (19/20 ov)',
#  'Chennai Super Kings won by 7 wickets',
#  '70 (15/20 ov)',
#  '71/4 (13/20 ov)',
#  'Rajasthan Royals won by 6 wickets',
#  '132/9 (20 ov)',
#  '109 (18.2/20 ov)',
#  'Kings XI Punjab won by 23 runs',
#  '125/6 (20 ov)',
#  '126/4 (18.5/20 ov)',
#  'Delhi Daredevils won by 6 wickets',
#  '145/5 (20 ov)',
#  '146/5 (19.3/20 ov)',
#  'Chennai Super Kings won by 5 wickets',
#  '124/8 (20 ov)',
#  '127/5 (18.5/20 ov)',
#  'Kings XI Punjab won by 5 wickets',
#  '152/5 (20 ov)',
#  '152/8 (20 ov)',
#  'Match tied (Rajasthan Royals won the one-over eliminator)',
#  '172/5 (20 ov)',
#  '157/7 (20 ov)',
#  'Sunrisers Hyderabad won by 15 runs',
#  '148/3 (17 ov)',
#  '114/9 (17 ov)',
#  'Chennai Super Kings won by 34 runs',
#  '168/5 (20 ov)',
#  '170/5 (19.1/20 ov)',
#  'Mumbai Indians won by 5 wickets',
#  '152/5 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  'Rajasthan Royals won by 7 wickets',
#  '155/6 (20 ov)',
#  '158/6 (19.5/20 ov)',
#  'Royal Challengers Bangalore won by 4 wickets',
#  '170/6 (20 ov)',
#  '160/6 (20 ov)',
#  'Rajasthan Royals won by 10 runs',
#  '178/5 (20 ov)',
#  '181/2 (19.4/20 ov)',
#  'Chennai Super Kings won by 8 wickets',
#  '187/5 (20 ov)',
#  '168/8 (20 ov)',
#  'Mumbai Indians won by 19 runs',
#  '160/5 (20 ov)',
#  '161/2 (18.2/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets',
#  '231/4 (20 ov)',
#  '187/6 (20 ov)',
#  'Kings XI Punjab won by 44 runs',
#  '134/9 (20 ov)',
#  '102 (19.5/20 ov)',
#  'Sunrisers Hyderabad won by 32 runs',
#  '198/8 (20 ov)',
#  '166/9 (20 ov)',
#  'Kings XI Punjab won by 32 runs',
#  '143/7 (20 ov)',
#  '44/2 (4.2/5 ov, target: 43)',
#  'Sunrisers Hyderabad won by 8 wickets (D/L method)',
#  '157/6 (20 ov)',
#  '160/6 (19.3/20 ov)',
#  'Chennai Super Kings won by 4 wickets',
#  '149/8 (20 ov)',
#  '150/1 (18/20 ov)',
#  'Kolkata Knight Riders won by 9 wickets',
#  '190/5 (20 ov)',
#  '191/5 (18.5/20 ov)',
#  'Rajasthan Royals won by 5 wickets',
#  '157/3 (20 ov)',
#  '160/3 (18.4/20 ov)',
#  'Mumbai Indians won by 7 wickets',
#  '148/8 (20 ov)',
#  '149/5 (19.4/20 ov)',
#  'Chennai Super Kings won by 5 wickets',
#  '186/4 (20 ov)',
#  '170/7 (20 ov)',
#  'Royal Challengers Bangalore won by 16 runs',
#  '205/5 (20 ov)',
#  '211/4 (18.4/20 ov)',
#  'Kings XI Punjab won by 6 wickets',
#  '141/5 (20 ov)',
#  '142/4 (18.4/20 ov)',
#  'Kolkata Knight Riders won by 6 wickets',
#  '201/6 (20 ov)',
#  '139/9 (20 ov)',
#  'Rajasthan Royals won by 62 runs',
#  '138/4 (20 ov)',
#  '142/5 (19.5/20 ov)',
#  'Royal Challengers Bangalore won by 5 wickets',
#  '142/8 (20 ov)',
#  '146/3 (19.4/20 ov)',
#  'Kolkata Knight Riders won by 7 wickets',
#  '178/3 (20 ov)',
#  '153/8 (20 ov)',
#  'Mumbai Indians won by 25 runs',
#  '164/7 (20 ov)',
#  '165/6 (19.4/20 ov)',
#  'Kings XI Punjab won by 4 wickets',
#  '160/6 (20 ov)',
#  '161/3 (19.4/20 ov)',
#  'Sunrisers Hyderabad won by 7 wickets',
#  '154/4 (20 ov)',
#  '156/2 (18/20 ov)',
#  'Kolkata Knight Riders won by 8 wickets',
#  '156/8 (20 ov)',
#  '159/3 (19/20 ov)',
#  'Mumbai Indians won by 7 wickets',
#  '195/4 (20 ov)',
#  '165/5 (20 ov)',
#  'Kolkata Knight Riders won by 30 runs',
#  '185/3 (20 ov)',
#  '189/4 (19.4/20 ov)',
#  'Sunrisers Hyderabad won by 6 wickets',
#  '173 (19.3/20 ov)',
#  '158/4 (20 ov)',
#  'Mumbai Indians won by 15 runs',
#  '179/4 (20 ov)',
#  '163/8 (20 ov)',
#  'Kings XI Punjab won by 16 runs',
#  '154/6 (20 ov)',
#  '160/2 (17.4/20 ov)',
#  'Chennai Super Kings won by 8 wickets',
#  '160/7 (20 ov)',
#  '161/6 (14.2/20 ov)',
#  'Kolkata Knight Riders won by 4 wickets',
#  '115 (18.1/20 ov)',
#  '119/3 (13.5/20 ov)',
#  'Kings XI Punjab won by 7 wickets',
#  '189/4 (20 ov)',
#  '195/5 (14.4/20 ov)',
#  'Mumbai Indians won by 5 wickets',
#  '163/8 (20 ov)',
#  '135/8 (20 ov)',
#  'Kolkata Knight Riders won by 28 runs',
#  '173/8 (20 ov)',
#  '176/3 (18.4/20 ov)',
#  'Chennai Super Kings won by 7 wickets',
#  '226/6 (20 ov)',
#  '202/7 (20 ov)',
#  'Kings XI Punjab won by 24 runs',
#  '199/4 (20 ov)',
#  '200/7 (19.3/20 ov)',
#  'Kolkata Knight Riders won by 3 wickets']

# %%
z=[]
for i in range(1,len(y)):
    if i%3 != 0:
        z.append(y[i-1]) 
z
# Out:
# ['163/5 (20 ov)',
#  '122/7 (20 ov)',
#  '145/4 (20 ov)',
#  '146/2 (16.4/20 ov)',
#  '205/4 (20 ov)',
#  '206/4 (18.5/20 ov)',
#  '133/6 (20 ov)',
#  '135/6 (19.3/20 ov)',
#  '115/9 (20 ov)',
#  '116/3 (17.3/20 ov)',
#  '166/5 (20 ov)',
#  '167/6 (19.3/20 ov)',
#  '191/5 (20 ov)',
#  '193/3 (18.4/20 ov)',
#  '177/7 (20 ov)',
#  '84 (15.4/20 ov)',
#  '193/6 (20 ov)',
#  '121 (19.2/20 ov)',
#  '140/6 (20 ov)',
#  '133 (19.5/20 ov)',
#  '150/7 (20 ov)',
#  '148/5 (20 ov)',
#  '184/1 (20 ov)',
#  '180/4 (20 ov)',
#  '141/7 (20 ov)',
#  '142/3 (19/20 ov)',
#  '70 (15/20 ov)',
#  '71/4 (13/20 ov)',
#  '132/9 (20 ov)',
#  '109 (18.2/20 ov)',
#  '125/6 (20 ov)',
#  '126/4 (18.5/20 ov)',
#  '145/5 (20 ov)',
#  '146/5 (19.3/20 ov)',
#  '124/8 (20 ov)',
#  '127/5 (18.5/20 ov)',
#  '152/5 (20 ov)',
#  '152/8 (20 ov)',
#  '172/5 (20 ov)',
#  '157/7 (20 ov)',
#  '148/3 (17 ov)',
#  '114/9 (17 ov)',
#  '168/5 (20 ov)',
#  '170/5 (19.1/20 ov)',
#  '152/5 (20 ov)',
#  '156/3 (18.3/20 ov)',
#  '155/6 (20 ov)',
#  '158/6 (19.5/20 ov)',
#  '170/6 (20 ov)',
#  '160/6 (20 ov)',
#  '178/5 (20 ov)',
#  '181/2 (19.4/20 ov)',
#  '187/5 (20 ov)',
#  '168/8 (20 ov)',
#  '160/5 (20 ov)',
#  '161/2 (18.2/20 ov)',
#  '231/4 (20 ov)',
#  '187/6 (20 ov)',
#  '134/9 (20 ov)',
#  '102 (19.5/20 ov)',
#  '198/8 (20 ov)',
#  '166/9 (20 ov)',
#  '143/7 (20 ov)',
#  '44/2 (4.2/5 ov, target: 43)',
#  '157/6 (20 ov)',
#  '160/6 (19.3/20 ov)',
#  '149/8 (20 ov)',
#  '150/1 (18/20 ov)',
#  '190/5 (20 ov)',
#  '191/5 (18.5/20 ov)',
#  '157/3 (20 ov)',
#  '160/3 (18.4/20 ov)',
#  '148/8 (20 ov)',
#  '149/5 (19.4/20 ov)',
#  '186/4 (20 ov)',
#  '170/7 (20 ov)',
#  '205/5 (20 ov)',
#  '211/4 (18.4/20 ov)',
#  '141/5 (20 ov)',
#  '142/4 (18.4/20 ov)',
#  '201/6 (20 ov)',
#  '139/9 (20 ov)',
#  '138/4 (20 ov)',
#  '142/5 (19.5/20 ov)',
#  '142/8 (20 ov)',
#  '146/3 (19.4/20 ov)',
#  '178/3 (20 ov)',
#  '153/8 (20 ov)',
#  '164/7 (20 ov)',
#  '165/6 (19.4/20 ov)',
#  '160/6 (20 ov)',
#  '161/3 (19.4/20 ov)',
#  '154/4 (20 ov)',
#  '156/2 (18/20 ov)',
#  '156/8 (20 ov)',
#  '159/3 (19/20 ov)',
#  '195/4 (20 ov)',
#  '165/5 (20 ov)',
#  '185/3 (20 ov)',
#  '189/4 (19.4/20 ov)',
#  '173 (19.3/20 ov)',
#  '158/4 (20 ov)',
#  '179/4 (20 ov)',
#  '163/8 (20 ov)',
#  '154/6 (20 ov)',
#  '160/2 (17.4/20 ov)',
#  '160/7 (20 ov)',
#  '161/6 (14.2/20 ov)',
#  '115 (18.1/20 ov)',
#  '119/3 (13.5/20 ov)',
#  '189/4 (20 ov)',
#  '195/5 (14.4/20 ov)',
#  '163/8 (20 ov)',
#  '135/8 (20 ov)',
#  '173/8 (20 ov)',
#  '176/3 (18.4/20 ov)',
#  '226/6 (20 ov)',
#  '202/7 (20 ov)',
#  '199/4 (20 ov)',
#  '200/7 (19.3/20 ov)']

# %%
run=[]
for i in z:
    p=[]
    for k in i:
        if k != '/' and k !=' ':
            p.append(k)
        if k == '/' or k ==' ':
            break
    run.append(p)
run
# Out:
# [['1', '6', '3'],
#  ['1', '2', '2'],
#  ['1', '4', '5'],
#  ['1', '4', '6'],
#  ['2', '0', '5'],
#  ['2', '0', '6'],
#  ['1', '3', '3'],
#  ['1', '3', '5'],
#  ['1', '1', '5'],
#  ['1', '1', '6'],
#  ['1', '6', '6'],
#  ['1', '6', '7'],
#  ['1', '9', '1'],
#  ['1', '9', '3'],
#  ['1', '7', '7'],
#  ['8', '4'],
#  ['1', '9', '3'],
#  ['1', '2', '1'],
#  ['1', '4', '0'],
#  ['1', '3', '3'],
#  ['1', '5', '0'],
#  ['1', '4', '8'],
#  ['1', '8', '4'],
#  ['1', '8', '0'],
#  ['1', '4', '1'],
#  ['1', '4', '2'],
#  ['7', '0'],
#  ['7', '1'],
#  ['1', '3', '2'],
#  ['1', '0', '9'],
#  ['1', '2', '5'],
#  ['1', '2', '6'],
#  ['1', '4', '5'],
#  ['1', '4', '6'],
#  ['1', '2', '4'],
#  ['1', '2', '7'],
#  ['1', '5', '2'],
#  ['1', '5', '2'],
#  ['1', '7', '2'],
#  ['1', '5', '7'],
#  ['1', '4', '8'],
#  ['1', '1', '4'],
#  ['1', '6', '8'],
#  ['1', '7', '0'],
#  ['1', '5', '2'],
#  ['1', '5', '6'],
#  ['1', '5', '5'],
#  ['1', '5', '8'],
#  ['1', '7', '0'],
#  ['1', '6', '0'],
#  ['1', '7', '8'],
#  ['1', '8', '1'],
#  ['1', '8', '7'],
#  ['1', '6', '8'],
#  ['1', '6', '0'],
#  ['1', '6', '1'],
#  ['2', '3', '1'],
#  ['1', '8', '7'],
#  ['1', '3', '4'],
#  ['1', '0', '2'],
#  ['1', '9', '8'],
#  ['1', '6', '6'],
#  ['1', '4', '3'],
#  ['4', '4'],
#  ['1', '5', '7'],
#  ['1', '6', '0'],
#  ['1', '4', '9'],
#  ['1', '5', '0'],
#  ['1', '9', '0'],
#  ['1', '9', '1'],
#  ['1', '5', '7'],
#  ['1', '6', '0'],
#  ['1', '4', '8'],
#  ['1', '4', '9'],
#  ['1', '8', '6'],
#  ['1', '7', '0'],
#  ['2', '0', '5'],
#  ['2', '1', '1'],
#  ['1', '4', '1'],
#  ['1', '4', '2'],
#  ['2', '0', '1'],
#  ['1', '3', '9'],
#  ['1', '3', '8'],
#  ['1', '4', '2'],
#  ['1', '4', '2'],
#  ['1', '4', '6'],
#  ['1', '7', '8'],
#  ['1', '5', '3'],
#  ['1', '6', '4'],
#  ['1', '6', '5'],
#  ['1', '6', '0'],
#  ['1', '6', '1'],
#  ['1', '5', '4'],
#  ['1', '5', '6'],
#  ['1', '5', '6'],
#  ['1', '5', '9'],
#  ['1', '9', '5'],
#  ['1', '6', '5'],
#  ['1', '8', '5'],
#  ['1', '8', '9'],
#  ['1', '7', '3'],
#  ['1', '5', '8'],
#  ['1', '7', '9'],
#  ['1', '6', '3'],
#  ['1', '5', '4'],
#  ['1', '6', '0'],
#  ['1', '6', '0'],
#  ['1', '6', '1'],
#  ['1', '1', '5'],
#  ['1', '1', '9'],
#  ['1', '8', '9'],
#  ['1', '9', '5'],
#  ['1', '6', '3'],
#  ['1', '3', '5'],
#  ['1', '7', '3'],
#  ['1', '7', '6'],
#  ['2', '2', '6'],
#  ['2', '0', '2'],
#  ['1', '9', '9'],
#  ['2', '0', '0']]

# %%
runs=[]
for i in run:
    runs.append("".join(i))
runs
# Out:
# ['163',
#  '122',
#  '145',
#  '146',
#  '205',
#  '206',
#  '133',
#  '135',
#  '115',
#  '116',
#  '166',
#  '167',
#  '191',
#  '193',
#  '177',
#  '84',
#  '193',
#  '121',
#  '140',
#  '133',
#  '150',
#  '148',
#  '184',
#  '180',
#  '141',
#  '142',
#  '70',
#  '71',
#  '132',
#  '109',
#  '125',
#  '126',
#  '145',
#  '146',
#  '124',
#  '127',
#  '152',
#  '152',
#  '172',
#  '157',
#  '148',
#  '114',
#  '168',
#  '170',
#  '152',
#  '156',
#  '155',
#  '158',
#  '170',
#  '160',
#  '178',
#  '181',
#  '187',
#  '168',
#  '160',
#  '161',
#  '231',
#  '187',
#  '134',
#  '102',
#  '198',
#  '166',
#  '143',
#  '44',
#  '157',
#  '160',
#  '149',
#  '150',
#  '190',
#  '191',
#  '157',
#  '160',
#  '148',
#  '149',
#  '186',
#  '170',
#  '205',
#  '211',
#  '141',
#  '142',
#  '201',
#  '139',
#  '138',
#  '142',
#  '142',
#  '146',
#  '178',
#  '153',
#  '164',
#  '165',
#  '160',
#  '161',
#  '154',
#  '156',
#  '156',
#  '159',
#  '195',
#  '165',
#  '185',
#  '189',
#  '173',
#  '158',
#  '179',
#  '163',
#  '154',
#  '160',
#  '160',
#  '161',
#  '115',
#  '119',
#  '189',
#  '195',
#  '163',
#  '135',
#  '173',
#  '176',
#  '226',
#  '202',
#  '199',
#  '200']

# %%
for k in range(0,len(runs)):
    if runs[k]=='':
        runs[k]=0
runs
# Out:
# ['163',
#  '122',
#  '145',
#  '146',
#  '205',
#  '206',
#  '133',
#  '135',
#  '115',
#  '116',
#  '166',
#  '167',
#  '191',
#  '193',
#  '177',
#  '84',
#  '193',
#  '121',
#  '140',
#  '133',
#  '150',
#  '148',
#  '184',
#  '180',
#  '141',
#  '142',
#  '70',
#  '71',
#  '132',
#  '109',
#  '125',
#  '126',
#  '145',
#  '146',
#  '124',
#  '127',
#  '152',
#  '152',
#  '172',
#  '157',
#  '148',
#  '114',
#  '168',
#  '170',
#  '152',
#  '156',
#  '155',
#  '158',
#  '170',
#  '160',
#  '178',
#  '181',
#  '187',
#  '168',
#  '160',
#  '161',
#  '231',
#  '187',
#  '134',
#  '102',
#  '198',
#  '166',
#  '143',
#  '44',
#  '157',
#  '160',
#  '149',
#  '150',
#  '190',
#  '191',
#  '157',
#  '160',
#  '148',
#  '149',
#  '186',
#  '170',
#  '205',
#  '211',
#  '141',
#  '142',
#  '201',
#  '139',
#  '138',
#  '142',
#  '142',
#  '146',
#  '178',
#  '153',
#  '164',
#  '165',
#  '160',
#  '161',
#  '154',
#  '156',
#  '156',
#  '159',
#  '195',
#  '165',
#  '185',
#  '189',
#  '173',
#  '158',
#  '179',
#  '163',
#  '154',
#  '160',
#  '160',
#  '161',
#  '115',
#  '119',
#  '189',
#  '195',
#  '163',
#  '135',
#  '173',
#  '176',
#  '226',
#  '202',
#  '199',
#  '200']

# %%
over=[]
for k in z:
    w=[]
    for t in range(len(k)):
        if k[t]=='(':
            w.append(k[t+1])
            if k[t+2] != " ":   
                w.append(k[t+2])
            if k[t+3] != ' ' and k[t+3] != '/' and k[t+3] !='o':
                w.append(k[t+3])
                if k[t+3]=='.':
                    w.append(k[t+4])
            break
    over.append(w)        
over
# Out:
# [['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '6', '.', '4'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '7', '.', '3'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['1', '5', '.', '4'],
#  ['2', '0'],
#  ['1', '9', '.', '2'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9'],
#  ['1', '5'],
#  ['1', '3'],
#  ['2', '0'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7'],
#  ['1', '7'],
#  ['2', '0'],
#  ['1', '9', '.', '1'],
#  ['2', '0'],
#  ['1', '8', '.', '3'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '2'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['4', '.', '2'],
#  ['2', '0'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['1', '8'],
#  ['2', '0'],
#  ['1', '8', '.', '5'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '5'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['2', '0'],
#  ['1', '8'],
#  ['2', '0'],
#  ['1', '9'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '4'],
#  ['1', '9', '.', '3'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '7', '.', '4'],
#  ['2', '0'],
#  ['1', '4', '.', '2'],
#  ['1', '8', '.', '1'],
#  ['1', '3', '.', '5'],
#  ['2', '0'],
#  ['1', '4', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '8', '.', '4'],
#  ['2', '0'],
#  ['2', '0'],
#  ['2', '0'],
#  ['1', '9', '.', '3']]

# %%
overs=[]
for i in over:
    overs.append("".join(i))
    
overs
# Out:
# ['20',
#  '20',
#  '20',
#  '16.4',
#  '20',
#  '18.5',
#  '20',
#  '19.3',
#  '20',
#  '17.3',
#  '20',
#  '19.3',
#  '20',
#  '18.4',
#  '20',
#  '15.4',
#  '20',
#  '19.2',
#  '20',
#  '19.5',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '19',
#  '15',
#  '13',
#  '20',
#  '18.2',
#  '20',
#  '18.5',
#  '20',
#  '19.3',
#  '20',
#  '18.5',
#  '20',
#  '20',
#  '20',
#  '20',
#  '17',
#  '17',
#  '20',
#  '19.1',
#  '20',
#  '18.3',
#  '20',
#  '19.5',
#  '20',
#  '20',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '18.2',
#  '20',
#  '20',
#  '20',
#  '19.5',
#  '20',
#  '20',
#  '20',
#  '4.2',
#  '20',
#  '19.3',
#  '20',
#  '18',
#  '20',
#  '18.5',
#  '20',
#  '18.4',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '18.4',
#  '20',
#  '18.4',
#  '20',
#  '20',
#  '20',
#  '19.5',
#  '20',
#  '19.4',
#  '20',
#  '20',
#  '20',
#  '19.4',
#  '20',
#  '19.4',
#  '20',
#  '18',
#  '20',
#  '19',
#  '20',
#  '20',
#  '20',
#  '19.4',
#  '19.3',
#  '20',
#  '20',
#  '20',
#  '20',
#  '17.4',
#  '20',
#  '14.2',
#  '18.1',
#  '13.5',
#  '20',
#  '14.4',
#  '20',
#  '20',
#  '20',
#  '18.4',
#  '20',
#  '20',
#  '20',
#  '19.3']

# %%
runs1=[]
runs2=[]
for i in range(len(runs)):
    if i%2 ==0:
        
        runs1.append(runs[i])
    else:
        runs2.append(runs[i])
overs1=[]
overs2=[]
for i in range(len(overs)):
    if i%2 ==0:
        
        overs1.append(overs[i])
    else:
        overs2.append(overs[i]) 
print(len(runs1))
print(len(runs2))
print(len(overs1))
print(len(overs2))
# Out:
# 60
# 60
# 60
# 60

# %%
r1=[]
for i in runs1:
    r1.append(float(i))
r2=[]
for i in runs2:
    r2.append(float(i))

# %%
o1=[]
for i in overs1:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o1.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o1.append(u)
    elif (len(i)==0):
        o1.append(1)
print(len(o1)) 
print(o1)

o2=[]
for i in overs2:
    if(len(i)==4):
        g=int(i[0])*10+int(i[1])+int(i[3])*0.1
        o2.append(g)
    elif (len(i)==2):
        u=int(i[0])*10+int(i[1])
        o2.append(u)
    elif (len(i)==0):
        o2.append(1)
    elif (len(i)==3):
        j=int(i[0])+int(i[2])*0.1
        o2.append(j)
    elif (len(i)==1):
        o2.append(int(i))
print(len(o2)) 
print(o2)
# Out:
# 60
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 15, 20, 20, 20, 20, 20, 20, 17, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 19.3, 20, 20, 20, 18.1, 20, 20, 20, 20, 20]
# 60
# [20, 16.4, 18.5, 19.3, 17.3, 19.3, 18.4, 15.4, 19.2, 19.5, 20, 20, 19, 13, 18.2, 18.5, 19.3, 18.5, 20, 20, 17, 19.1, 18.3, 19.5, 20, 19.4, 20, 18.2, 20, 19.5, 20, 4.2, 19.3, 18, 18.5, 18.4, 19.4, 20, 18.4, 18.4, 20, 19.5, 19.4, 20, 19.4, 19.4, 18, 19, 20, 19.4, 20, 20, 17.4, 14.2, 13.5, 14.4, 20, 18.4, 20, 19.3]

# %%
runrate1=[]
for i in range(len(o1)):
    runrate1.append((float(r1[i])/float(o1[i]))-(float(r2[i])/float(o2[i])))
runrate1
# Out:
# [2.0500000000000007,
#  -1.6524390243902438,
#  -0.8851351351351351,
#  -0.34481865284974056,
#  -0.9552023121387281,
#  -0.3528497409326423,
#  -0.9391304347826086,
#  3.3954545454545455,
#  3.3479166666666664,
#  0.17948717948717974,
#  0.09999999999999964,
#  0.1999999999999993,
#  -0.4236842105263161,
#  -0.7948717948717947,
#  0.6109890109890106,
#  -0.5608108108108105,
#  -0.3147668393782377,
#  -0.6648648648648647,
#  0.0,
#  0.75,
#  1.9999999999999991,
#  -0.5005235602094231,
#  -0.9245901639344254,
#  -0.3525641025641022,
#  0.5,
#  -0.4298969072164951,
#  0.9499999999999993,
#  -0.8461538461538467,
#  2.200000000000001,
#  1.4692307692307693,
#  1.5999999999999996,
#  -3.326190476190476,
#  -0.4401554404145074,
#  -0.8833333333333337,
#  -0.8243243243243246,
#  -0.8456521739130451,
#  -0.2804123711340205,
#  0.8000000000000007,
#  -1.2173913043478262,
#  -0.6673913043478272,
#  3.1000000000000005,
#  -0.3820512820512816,
#  -0.4257731958762898,
#  1.25,
#  -0.3051546391752584,
#  -0.29896907216494917,
#  -0.9666666666666659,
#  -0.5684210526315789,
#  1.5,
#  -0.4922680412371143,
#  1.063730569948186,
#  0.7999999999999989,
#  -1.4954022988505757,
#  -3.338028169014086,
#  -2.4612236545938213,
#  -4.091666666666667,
#  1.4000000000000004,
#  -0.9152173913043491,
#  1.200000000000001,
#  -0.41269430051813494]

# %%
runrate2=[]
for i in runrate1:
    runrate2.append(-i)
runrate2
# Out:
# [-2.0500000000000007,
#  1.6524390243902438,
#  0.8851351351351351,
#  0.34481865284974056,
#  0.9552023121387281,
#  0.3528497409326423,
#  0.9391304347826086,
#  -3.3954545454545455,
#  -3.3479166666666664,
#  -0.17948717948717974,
#  -0.09999999999999964,
#  -0.1999999999999993,
#  0.4236842105263161,
#  0.7948717948717947,
#  -0.6109890109890106,
#  0.5608108108108105,
#  0.3147668393782377,
#  0.6648648648648647,
#  -0.0,
#  -0.75,
#  -1.9999999999999991,
#  0.5005235602094231,
#  0.9245901639344254,
#  0.3525641025641022,
#  -0.5,
#  0.4298969072164951,
#  -0.9499999999999993,
#  0.8461538461538467,
#  -2.200000000000001,
#  -1.4692307692307693,
#  -1.5999999999999996,
#  3.326190476190476,
#  0.4401554404145074,
#  0.8833333333333337,
#  0.8243243243243246,
#  0.8456521739130451,
#  0.2804123711340205,
#  -0.8000000000000007,
#  1.2173913043478262,
#  0.6673913043478272,
#  -3.1000000000000005,
#  0.3820512820512816,
#  0.4257731958762898,
#  -1.25,
#  0.3051546391752584,
#  0.29896907216494917,
#  0.9666666666666659,
#  0.5684210526315789,
#  -1.5,
#  0.4922680412371143,
#  -1.063730569948186,
#  -0.7999999999999989,
#  1.4954022988505757,
#  3.338028169014086,
#  2.4612236545938213,
#  4.091666666666667,
#  -1.4000000000000004,
#  0.9152173913043491,
#  -1.200000000000001,
#  0.41269430051813494]

# %%
rr2014 = pd.DataFrame(runrate1,runrate2)
rr2014.to_csv('rr2014.csv')
