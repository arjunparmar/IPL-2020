# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
ismale = pd.get_dummies(df['Gender'],drop_first=True)
df = pd.concat([df, ismale], axis=1)
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased  Male
# 0  15624510    Male   19            19000          0     1
# 1  15810944    Male   35            20000          0     1
# 2  15668575  Female   26            43000          0     0
# 3  15603246  Female   27            57000          0     0
# 4  15804002    Male   19            76000          0     1

# %%
df.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased      Male
# User ID          1.000000 -0.000721         0.071097   0.007120 -0.025249
# Age             -0.000721  1.000000         0.155238   0.622454 -0.073741
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083 -0.060435
# Purchased        0.007120  0.622454         0.362083   1.000000 -0.042469
# Male            -0.025249 -0.073741        -0.060435  -0.042469  1.000000

# %% [markdown]
# ##Considering Age and Estimated Salary as features

# %%
x = df[['Age', 'EstimatedSalary']].values
x = (x - np.mean(x))/np.std(x)
x = np.column_stack((np.ones((x.shape[0],1)),x))
y = df['Purchased'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=35)

# %%
def a(x, B):
  return x@B

# %%
def sig(a):
  return (1/(1+np.exp(-a)))

# %%
def loss(yp,y):
  return (-1/y.shape[0])*(y.T@np.log(yp)+(1-y).T@np.log(1-yp))

# %%
B = np.zeros((x_train.shape[1],1))
m = x_train.shape[0]
alpha = 3.5
L =[]
y_train=y_train.reshape(x_train.shape[0],-1)
for i in range(2000):
  k = a(x_train, B)
  z = sig(k)
  dB = (1/m)*np.dot(x_train.T,(z-y_train))
  B = B-dB*alpha
  L.append(loss(z,y_train))
print(L)
# Out:
# [array([[0.69314718]]), array([[0.64718085]]), array([[0.62978161]]), array([[0.62509648]]), array([[0.62200833]]), array([[0.61955987]]), array([[0.61698134]]), array([[0.61306514]]), array([[0.61037435]]), array([[0.60652349]]), array([[0.60424309]]), array([[0.60123562]]), array([[0.59950525]]), array([[0.59735966]]), array([[0.59610461]]), array([[0.5946164]]), array([[0.59371687]]), array([[0.59268471]]), array([[0.59203715]]), array([[0.59131269]]), array([[0.59084108]]), array([[0.59032429]]), array([[0.58997602]]), array([[0.58960122]]), array([[0.58934052]]), array([[0.58906454]]), array([[0.58886704]]), array([[0.58866113]]), array([[0.58851]]), array([[0.58835467]]), array([[0.58823809]]), array([[0.58811986]]), array([[0.58802935]]), array([[0.5879387]]), array([[0.58786808]]), array([[0.58779816]]), array([[0.58774286]]), array([[0.58768869]]), array([[0.58764524]]), array([[0.58760311]]), array([[0.58756892]]), array([[0.58753605]]), array([[0.58750909]]), array([[0.58748339]]), array([[0.58746211]]), array([[0.58744197]]), array([[0.58742516]]), array([[0.58740935]]), array([[0.58739606]]), array([[0.58738363]]), array([[0.58737312]]), array([[0.58736334]]), array([[0.58735503]]), array([[0.58734733]]), array([[0.58734075]]), array([[0.58733468]]), array([[0.58732947]]), array([[0.58732468]]), array([[0.58732056]]), array([[0.58731678]]), array([[0.58731352]]), array([[0.58731053]]), array([[0.58730795]]), array([[0.58730559]]), array([[0.58730354]]), array([[0.58730168]]), array([[0.58730006]]), array([[0.58729859]]), array([[0.5872973]]), array([[0.58729614]]), array([[0.58729511]]), array([[0.58729419]]), array([[0.58729338]]), array([[0.58729265]]), array([[0.58729201]]), array([[0.58729143]]), array([[0.58729092]]), array([[0.58729046]]), array([[0.58729006]]), array([[0.58728969]]), array([[0.58728937]]), array([[0.58728908]]), array([[0.58728882]]), array([[0.58728859]]), array([[0.58728839]]), array([[0.5872882]]), array([[0.58728804]]), array([[0.58728789]]), array([[0.58728776]]), array([[0.58728764]]), array([[0.58728754]]), array([[0.58728744]]), array([[0.58728735]]), array([[0.58728728]]), array([[0.58728721]]), array([[0.58728714]]), array([[0.58728709]]), array([[0.58728704]]), array([[0.58728699]]), array([[0.58728695]]), array([[0.58728691]]), array([[0.58728687]]), array([[0.58728684]]), array([[0.58728681]]), array([[0.58728678]]), array([[0.58728676]]), array([[0.58728673]]), array([[0.58728671]]), array([[0.58728669]]), array([[0.58728667]]), array([[0.58728665]]), array([[0.58728664]]), array([[0.58728662]]), array([[0.5872866]]), array([[0.58728659]]), array([[0.58728658]]), array([[0.58728656]]), array([[0.58728655]]), array([[0.58728654]]), array([[0.58728653]]), array([[0.58728651]]), array([[0.5872865]]), array([[0.58728649]]), array([[0.58728648]]), array([[0.58728647]]), array([[0.58728646]]), array([[0.58728645]]), array([[0.58728644]]), array([[0.58728643]]), array([[0.58728642]]), array([[0.58728641]]), array([[0.5872864]]), array([[0.58728639]]), array([[0.58728638]]), array([[0.58728637]]), array([[0.58728636]]), array([[0.58728635]]), array([[0.58728635]]), array([[0.58728634]]), array([[0.58728633]]), array([[0.58728632]]), array([[0.58728631]]), array([[0.5872863]]), array([[0.58728629]]), array([[0.58728628]]), array([[0.58728627]]), array([[0.58728626]]), array([[0.58728626]]), array([[0.58728625]]), array([[0.58728624]]), array([[0.58728623]]), array([[0.58728622]]), array([[0.58728621]]), array([[0.5872862]]), array([[0.58728619]]), array([[0.58728619]]), array([[0.58728618]]), array([[0.58728617]]), array([[0.58728616]]), array([[0.58728615]]), array([[0.58728614]]), array([[0.58728613]]), array([[0.58728612]]), array([[0.58728612]]), array([[0.58728611]]), array([[0.5872861]]), array([[0.58728609]]), array([[0.58728608]]), array([[0.58728607]]), array([[0.58728606]]), array([[0.58728605]]), array([[0.58728605]]), array([[0.58728604]]), array([[0.58728603]]), array([[0. ...

# %%
print(B)
# Out:
# [[-0.64869122]
#  [ 0.98639559]
#  [ 0.97839151]]

# %%
k = a(x_test,B)
y_test_p = sig(k)
for i in range(y_test_p.shape[0]):
  if y_test_p[i]>=0.53:
    y_test_p[i]=1
  else :
    y_test_p[i]=0
y_test_p=y_test_p.reshape(-1)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_test_p)
print(cm)
# Out:
# [[50  1]
#  [15 14]]

# %%
acc = (50 + 14)/(50+1+15+14)
print(acc)
# Out:
# 0.8

# %% [markdown]
# ##Considering only Age as feature

# %%
x = df[['Age']].values
x = (x - np.mean(x))/np.std(x)
x = np.column_stack((np.ones((x.shape[0],1)),x))
y = df['Purchased'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=35)

# %%
B = np.zeros((x_train.shape[1],1))
m = x_train.shape[0]
alpha = 2
L =[]
y_train=y_train.reshape(x_train.shape[0],-1)
for i in range(2000):
  k = a(x_train, B)
  z = sig(k)
  dB = (1/m)*np.dot(x_train.T,(z-y_train))
  B = B-dB*alpha
  L.append(loss(z,y_train))
print(L)
# Out:
# [array([[0.69314718]]), array([[0.54032274]]), array([[0.49036389]]), array([[0.46809103]]), array([[0.45618877]]), array([[0.44913217]]), array([[0.44466295]]), array([[0.4417013]]), array([[0.4396733]]), array([[0.43824994]]), array([[0.43723167]]), array([[0.43649209]]), array([[0.4359483]]), array([[0.43554445]]), array([[0.43524202]]), array([[0.43501397]]), array([[0.43484099]]), array([[0.43470914]]), array([[0.4346082]]), array([[0.43453064]]), array([[0.43447087]]), array([[0.43442467]]), array([[0.43438888]]), array([[0.4343611]]), array([[0.43433949]]), array([[0.43432266]]), array([[0.43430954]]), array([[0.43429929]]), array([[0.43429128]]), array([[0.43428501]]), array([[0.4342801]]), array([[0.43427625]]), array([[0.43427323]]), array([[0.43427087]]), array([[0.43426901]]), array([[0.43426755]]), array([[0.4342664]]), array([[0.4342655]]), array([[0.43426479]]), array([[0.43426423]]), array([[0.4342638]]), array([[0.43426345]]), array([[0.43426318]]), array([[0.43426297]]), array([[0.4342628]]), array([[0.43426267]]), array([[0.43426256]]), array([[0.43426248]]), array([[0.43426242]]), array([[0.43426237]]), array([[0.43426233]]), array([[0.43426229]]), array([[0.43426227]]), array([[0.43426225]]), array([[0.43426223]]), array([[0.43426222]]), array([[0.43426221]]), array([[0.4342622]]), array([[0.4342622]]), array([[0.43426219]]), array([[0.43426219]]), array([[0.43426219]]), array([[0.43426219]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0.43426218]]), array([[0 ...

# %%
print(B)
# Out:
# [[-0.9680898 ]
#  [ 1.92850225]]

# %%
k = a(x_test,B)
y_test_p = sig(k)
for i in range(y_test_p.shape[0]):
  if y_test_p[i]>=0.50:
    y_test_p[i]=1
  else :
    y_test_p[i]=0
y_test_p=y_test_p.reshape(-1)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_test_p)
print(cm)
# Out:
# [[50  1]
#  [ 9 20]]

# %%
acc = (50+20)/(50+1+9+20)
print(acc)
# Out:
# 0.875
